# %% [markdown]
# # 📘 Jupyter Notebook Шпаргалка
#
# ## 🔑 Горячие клавиши
# **Command Mode (синяя рамка):**
# - `A` — вставить ячейку выше
# - `B` — вставить ячейку ниже
# - `X` — вырезать ячейку
# - `C` — копировать ячейку
# - `V` — вставить ячейку ниже
# - `D D` — удалить ячейку
# - `Z` — вернуть удалённую ячейку
# - `M` — Markdown-ячейка
# - `Y` — Code-ячейка
#
# **Edit Mode (зелёная рамка):**
# - `Ctrl + Enter` — выполнить ячейку
# - `Shift + Enter` — выполнить и перейти дальше
# - `Alt + Enter` — выполнить и вставить новую
#
# ## ✍️ Markdown для текста
# - Заголовки: `#`, `##`, `###`
# - **жирный текст**: **текст**
# - *курсив*: *текст*
# - Списки:
#   - `- элемент` или `* элемент`
#   - `1. элемент`
# - Код внутри строки: `` `print("hi")` ``
# - Блок кода:
#   ```python
#   print("Пример")

# %% [markdown]
# # Скачивание данных

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open("dano_dataset_travel.csv", "r", encoding="utf-8") as f:
    for i in range(2):
        print(f.readline())
# Out:
# order_online_payment_flg;account_rk;client_rk;order_rk;loyalty_program_type_nm;bundle_nm;order_type_cd;order_status_cd;party_first_order_dt;party_first_order_type_dt;free_cancel_booking_dttm;created_dttm;cancel_dttm;book_start_dttm;local_book_start_dttm;book_end_dttm;hotel_country;hotel_city;avia_dep_city;avia_arr_city;promo_code_discount_amt;loyalty_accrual_rub_amt;nominal_price_eur_amt;nominal_price_rub_amt;order_item_cnt;month_beginning_balance_rub;monthly_income_amt;suppress_email_flg;suppress_call_flg;bounce_cd;last_sms_success_flg;call_contact_6m_flg;call_contact_3m_flg;call_contact_1m_flg;good_email_address_flg;bad_email_address_flg;email_valid_flg;children_cnt;age;age_type_cd;parent_meeting_region_nm;delivery_region_category_cd;lvn_city_nm;lvn_state_nm;time_zone_delta_tm;time_zone_cd;last_used_product_cd;first_used_product_cd;mobile_phone_operator_nm;marital_status_cd;education_level_cd;birth_place;gender_cd;last_sms_dt;last_email_send_dt;last_session_dttm
#
# 1,0;209c833731e84d21b5b7e673e0fb848749b9e7d29cda64d92f9e2424394b90c0;f4959ffb27271192727050953ecb27a8a8a38af413f3d852bd2038cf24a72940;fe1c6ce13774d102c655df4c01d54c34d495ef3d4c7e638d5746c1c7adbcc5a0;Bravo;Pro;AIR;SUC;2019-12-12;2019-12-12;;2024-11-01 12:39:13.457847;;2024-11-05 21:15:00.000000;2024-11-05 21:15:00.000000;;;;Ижевск;Москва;0,0;;142,0;15018,0;1,0;9185,0;113900,0;0;0;;1,0;;;;;;1;0,0;31,0;A20;МО Северо-Восток;CIT;Г ЯРОСЛАВЛЬ;ЯРОСЛАВСКАЯ ОБЛ;03:00:00;003;MPL;MPL;Тинькофф Мобайл;;;ГОР ЯРОСЛАВЛЬ;M;2024-07-02;;2024-11-06 19:42:52.000000

# %% [markdown]
# **Разделитель - ;**

# %%
df = pd.read_csv("dano_dataset_travel.csv", sep=';')
# Out:
# C:\Users\Petr\AppData\Local\Temp\ipykernel_15616\1195759353.py:1: DtypeWarning: Columns (31,32,33,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("dano_dataset_travel.csv", sep=';')

# %% [markdown]
# # Беглый взгляд на данные

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 835938 entries, 0 to 835937
# Data columns (total 56 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   order_online_payment_flg     786885 non-null  object
#  1   account_rk                   835938 non-null  object
#  2   client_rk                    835938 non-null  object
#  3   order_rk                     835938 non-null  object
#  4   loyalty_program_type_nm      754957 non-null  object
#  5   bundle_nm                    588049 non-null  object
#  6   order_type_cd                786885 non-null  object
#  7   order_status_cd              779514 non-null  object
#  8   party_first_order_dt         786885 non-null  object
#  9   party_first_order_type_dt    786767 non-null  object
#  10  free_cancel_booking_dttm     75600 non-null   object
#  11  created_dttm                 786885 non-null  object
#  12  cancel_dttm                  0 non-null       float64
#  13  book_start_dttm              786885 non-null  object
#  14  local_book_start_dttm        786885 non-null  object
#  15  book_end_dttm                171548 non-null  object
#  16  hotel_country                162248 non-null  object
#  17  hotel_city                   162248 non-null  object
#  18  avia_dep_city                615275 non-null  object
#  19  avia_arr_city                615275 non-null  object
#  20  promo_code_discount_amt      615900 non-null  object
#  21  loyalty_accrual_rub_amt      475353 non-null  object
#  22  nominal_price_eur_amt        786885 non-null  object
#  23  nominal_price_rub_amt        786885 non-null  object
#  24  order_item_cnt               615337 non-null  object
#  25  month_beginning_balance_rub  776628 non-null  object
#  26  monthly_income_amt           673078 non-null  object
#  27  suppress_email_flg           835938 non-null  int64
#  28  suppress_call_flg            835938 non-null  int64
#  29  bounce_cd                    39675 non-null   object
#  30  last_sms_success_flg         833939 non-null  object
#  31  call_contact_6m_flg          271 non-null     object
#  32  call_contact_3m_flg          271 non-null     object
#  33  call_contact_1m_flg          271 non-null     object
#  34  good_email_address_flg       19798 non-null   object
#  35  bad_email_address_flg        19798 non-null   object
#  36  email_valid_flg              835938 non-null  int64
#  37  children_cnt                 719699 non-null  object
#  38  age                          835937 non-null  object
#  39  age_type_cd                  835690 non-null  object
#  40  parent_meeting_region_nm     786457 non-null  object
#  41  delivery_region_category_cd  835938 non-null  object
#  42  lvn_city_nm                  475969 non-null  object
#  43  lvn_state_nm                 783169 non-null  object
#  44  time_zone_delta_tm           835938 non-null  object
#  45  time_zone_cd                 835938 non-null  object
#  46  last_used_product_cd         835935 non-null  object
#  47  first_used_product_cd        833478 non-null  object
#  48  mobile_phone_operator_nm     834698 non-null  object
#  49  marital_status_cd            520888 non-null  object
#  50  education_level_cd           475104 non-null  object
#  51  birth_place                  832973 non-null  object
#  52  gender_cd                    825781 non-null  object
#  53  last_sms_dt                  833939 non-null  object
#  54  last_email_send_dt           19798 non-null   object
#  55  last_session_dttm            835938 non-null  object
# dtypes: float64(1), int64(3), object(52)
# memory usage: 357.2+ MB

# %%
nan_percent = df.isna().mean() * 100
print(nan_percent.sort_values())
# Out:
# suppress_email_flg               0.000000
# time_zone_cd                     0.000000
# time_zone_delta_tm               0.000000
# delivery_region_category_cd      0.000000
# email_valid_flg                  0.000000
# suppress_call_flg                0.000000
# last_session_dttm                0.000000
# order_rk                         0.000000
# client_rk                        0.000000
# account_rk                       0.000000
# age                              0.000120
# last_used_product_cd             0.000359
# age_type_cd                      0.029667
# mobile_phone_operator_nm         0.148336
# last_sms_success_flg             0.239133
# last_sms_dt                      0.239133
# first_used_product_cd            0.294280
# birth_place                      0.354691
# gender_cd                        1.215042
# book_start_dttm                  5.868019
# order_type_cd                    5.868019
# created_dttm                     5.868019
# nominal_price_eur_amt            5.868019
# nominal_price_rub_amt            5.868019
# party_first_order_dt             5.868019
# local_book_start_dttm            5.868019
# order_online_payment_flg         5.868019
# party_first_order_type_dt        5.882135
# parent_meeting_region_nm         5.919219
# lvn_state_nm                     6.312549
# order_status_cd                  6.749783
# month_beginning_balance_rub      7.095024
# loyalty_program_type_nm          9.687441
# children_cnt                    13.905218
# monthly_income_amt              19.482306
# promo_code_discount_amt         26.322287
# order_item_cnt                  26.389637
# avia_dep_city                   26.397053
# avia_arr_city                   26.397053
# bundle_nm                       29.653993
# marital_status_cd               37.688202
# lvn_city_nm                     43.061686
# loyalty_accrual_rub_amt         43.135376
# education_level_cd              43.165163
# book_end_dttm                   79.478382
# hotel_city                      80.590905
# hotel_country                   80.590905
# free_cancel_booking_dttm        90.956267
# bounce_cd                       95.253835
# bad_email_address_flg           97.631643
# good_email_address_flg          97.631643
# last_email_send_dt              97.631643
# call_contact_1m_flg             99.967581
# call_contact_3m_flg             99.967581
# call_contact_6m_flg             99.967581
# cancel_dttm                    100.000000
# dtype: float64

# %%
count_unique = df.nunique().sort_values()
print(len(count_unique))
count_unique
# Out:
# 56
# cancel_dttm                         0
# order_online_payment_flg            1
# call_contact_1m_flg                 1
# call_contact_3m_flg                 1
# call_contact_6m_flg                 1
# gender_cd                           2
# email_valid_flg                     2
# bad_email_address_flg               2
# good_email_address_flg              2
# last_sms_success_flg                2
# suppress_call_flg                   2
# suppress_email_flg                  2
# order_type_cd                       2
# delivery_region_category_cd         3
# age_type_cd                         4
# last_used_product_cd                4
# education_level_cd                  5
# marital_status_cd                   6
# order_status_cd                     7
# children_cnt                        8
# bundle_nm                           9
# first_used_product_cd               9
# order_item_cnt                      9
# bounce_cd                          10
# time_zone_delta_tm                 12
# time_zone_cd                       23
# loyalty_program_type_nm            36
# mobile_phone_operator_nm           60
# age                                79
# promo_code_discount_amt            88
# hotel_country                     133
# last_email_send_dt                256
# lvn_state_nm                      304
# last_sms_dt                       428
# parent_meeting_region_nm          476
# avia_dep_city                     532
# avia_arr_city                     541
# book_end_dttm                     558
# lvn_city_nm                      1586
# party_first_order_type_dt        2497
# party_first_order_dt             2500
# monthly_income_amt               2668
# nominal_price_eur_amt            3154
# hotel_city                       3248
# loyalty_accrual_rub_amt          8726
# free_cancel_booking_dttm        11325
# birth_place                     51954
# nominal_price_rub_amt           72052
# last_session_dttm               86892
# local_book_start_dttm           99276
# book_start_dttm                 99276
# month_beginning_balance_rub    103762
# account_rk                     133885
# client_rk                      148364
# created_dttm                   786883
# order_rk                       786886
# dtype: int64

# %%
df.sample(10).T
# Out:
#                                                                         799537  \
# order_online_payment_flg                                                   1,0
# account_rk                   5d44e7cf6290c1527e5bfd84c691acfcf637913669f263...
# client_rk                    5aabfd6621808e08c8c8ddb5e8d936c8a846674124c761...
# order_rk                     1696166340e95798f4b80d919201d972ed2a4277a7977c...
# loyalty_program_type_nm                                       AllAirLinesDebit
# bundle_nm                                                                  NaN
# order_type_cd                                                              AIR
# order_status_cd                                                            SUC
# party_first_order_dt                                                2023-03-15
# party_first_order_type_dt                                           2023-03-15
# free_cancel_booking_dttm                                                   NaN
# created_dttm                                        2024-08-25 15:19:12.345441
# cancel_dttm                                                                NaN
# book_start_dttm                                     2024-08-26 20:50:00.000000
# local_book_start_dttm                               2024-08-26 20:50:00.000000
# book_end_dttm                                                              NaN
# hotel_country                                                              NaN
# hotel_city                                                                 NaN
# avia_dep_city                                                        Челябинск
# avia_arr_city                                                          Душанбе
# promo_code_discount_amt                                                    0,0
# loyalty_accrual_rub_amt                                                    NaN
# nominal_price_eur_amt                                                    145,0
# nominal_price_rub_amt                                                  14715,0
# order_item_cnt                                                             1,0
# month_beginning_balance_rub                                              178,0
# monthly_income_amt                                                         NaN
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                       1,0
# call_contact_6m_flg                                                        NaN
# call_contact_3m_flg                                                        NaN
# call_contact_1m_flg                                                        NaN
# good_email_address_flg                                                     NaN
# bad_email_address_flg                                                      NaN
# email_valid_flg                                                              1
# children_cnt                                                               NaN
# age                                                                       23,0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                             Челябинск
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                        Г ЧЕЛЯБИНСК
# lvn_state_nm                                                   ЧЕЛЯБИНСКАЯ ОБЛ
# time_zone_delta_tm                                                    03:00:00
# time_zone_cd                                                                 3
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      MPL
# mobile_phone_operator_nm                                                Билайн
# marital_status_cd                                                          NaN
# education_level_cd                                                         NaN
# birth_place                                                        ТАДЖИКИСТАН
# gender_cd                                                                    M
# last_sms_dt                                                         2024-06-30
# last_email_send_dt                                                         NaN
# last_session_dttm                                   2024-11-06 15:51:43.000000
#
#                                                                         694089  \
# order_online_payment_flg                                                   1,0
# account_rk                   4572619dc77f63deaff7caf307bf6aef5248465aaa45c1...
# client_rk                    40a833012c3c4208727270cd5afb29874d0cf98e44710e...
# order_rk                     910df48625511f7f73e5843ae5486ebb6a93dfacf3a0d6...
# loyalty_program_type_nm                                                    NaN
# bundle_nm                                                              Premium
# order_type_cd                                                              AIR
# order_status_cd                                                            SUC
# party_first_order_dt                                                2022-10-07
# party_first_order_type_dt                                           2023-01-02
# free_cancel_booking_dttm                                                   NaN
# created_dttm                                        2024-01-22 14:12:45.226712
# cancel_dttm                                                                NaN
# book_start_dttm                                     2024-01-29 14:35:00.000000
# local_book_start_dttm                               2024-01-29 14:35:00.000000
# book_end_dttm                                                              NaN
# hotel_country                                                              NaN
# hotel_city                                                                 NaN
# avia_dep_city                                                           Казань
# avia_arr_city                                                  Санкт-Петербург
# promo_code_discount_amt                                                    0,0
# loyalty_accrual_rub_amt                                                    NaN
# nominal_price_eur_amt                                                     25,0
# nominal_price_rub_amt                                                   2391,0
# order_item_cnt                                                             2,0
# month_beginning_balance_rub                                             -577,0
# monthly_income_amt                                                    100500,0
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                       1,0
# call_contact_6m_flg                                                        NaN
# call_contact_3m_flg                                                        NaN
# call_contact_1m_flg                                                        NaN
# good_email_address_flg                                                     NaN
# bad_email_address_flg                                                      NaN
# email_valid_flg                                                              1
# children_cnt                                                               0,0
# age                                                                       33,0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                                Казань
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                           Г КАЗАНЬ
# lvn_state_nm                                                    РЕСП ТАТАРСТАН
# time_zone_delta_tm                                                    03:00:00
# time_zone_cd                                                               003
# last_used_product_cd                                                       IPL
# first_used_product_cd                                                      MPL
# mobile_phone_operator_nm                                                   МТС
# marital_status_cd                                                          MAR
# education_level_cd                                                         GRD
# birth_place                                               ГОР. САНКТ-ПЕТЕРБУРГ
# gender_cd                                                                    F
# last_sms_dt                                                         2024-11-05
# last_email_send_dt                                                         NaN
# last_session_dttm                                   2024-11-06 22:38:51.000000
#
#                                                                         355136  \
# order_online_payment_flg                                                   1,0
# account_rk                   9e809faa7c206b543d490a905bdb6c7e3d1ee089169eb1...
# client_rk                    c16b717822a82b6657ac469b94c8acc034f1ac89cdde0b...
# order_rk                     14745c0f0677940d083927994c3044415adf5f936baa05...
# loyalty_program_type_nm                                          Tinkoff Black
# bundle_nm                                                                  Pro
# order_type_cd                                                              AIR
# order_status_cd                                                            SUC
# party_first_order_dt                                                2020-04-12
# party_first_order_type_dt                                           2023-07-05
# free_cancel_booking_dttm                                                   NaN
# created_dttm                                        2024-05-16 08:39:41.551011
# cancel_dttm                                                                NaN
# book_start_dttm                                     2024-05-20 20:05:00.000000
# local_book_start_dttm                               2024-05-20 20:05:00.000000
# book_end_dttm                                                              NaN
# hotel_country                                                              NaN
# hotel_city                                                                 NaN
# avia_dep_city                                                           Самара
# avia_arr_city                                                     Екатеринбург
# promo_code_discount_amt                                                    0,0
# loyalty_accrual_rub_amt                                                  111,0
# nominal_price_eur_amt                                                     38,0
# nominal_price_rub_amt                                                   3712,0
# order_item_cnt                                                             1,0
# month_beginning_balance_rub                                             2842,0
# monthly_income_amt                                                     20100,0
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                       1,0
# call_contact_6m_flg                                                        NaN
# call_contact_3m_flg                                                        NaN
# call_contact_1m_flg                                                        NaN
# good_email_address_flg                                                     NaN
# bad_email_address_flg                                                      NaN
# email_valid_flg                                                              1
# children_cnt                                                               0,0
# age                                                                       26,0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                              Тольятти
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                         Г ТОЛЬЯТТИ
# lvn_state_nm                                                     САМАРСКАЯ ОБЛ
# time_zone_delta_tm                                                    04:00:00
# time_zone_cd                                                                 4
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      MPL
# mobile_phone_operator_nm                                                Билайн
# marital_status_cd                                                          UNM
# education_level_cd                                                         SCH
# birth_place                      Г ТОЛЬЯТТИ САМАРСКАЯ ОБЛ РОССИЙСКАЯ ФЕДЕРАЦИЯ
# gender_cd                                                                    M
# last_sms_dt                                                         2024-06-29
# last_email_send_dt                                                         NaN
# last_session_dttm                                   2024-11-06 20:36:33.000000
#
#                                                                         545177  \
# order_online_payment_flg                                                   1,0
# account_rk                   afae3de4240748013ec1c4afe1a7d0c180b33adbc399dd...
# client_rk                    3925e66ad4caf99d27d638b59b5548cc3f4e8b951ac61b...
# order_rk                     ce2087a31bf2838b6c40431fec6259d94c8ebd6588a7d9...
# loyalty_program_type_nm                                                    NaN
# bundle_nm                                                                  Pro
# order_type_cd                                                              AIR
# order_status_cd                                                            SUC
# party_first_order_dt                                                2024-04-04
# party_first_order_type_dt                                           2024-04-04
# free_cancel_booking_dttm                                                   NaN
# created_dttm                                        2024-05-22 08:58:16.109382
# cancel_dttm                                                                NaN
# book_start_dttm                                     2024-06-17 21:00:00.000000
# local_book_start_dttm                               2024-06-17 21:00:00.000000
# book_end_dttm                                                              NaN
# hotel_country                                                              NaN
# hotel_city                                                                 NaN
# avia_dep_city                                                          Саратов
# avia_arr_city                                                  Санкт-Петербург
# promo_code_discount_amt                                                    0,0
# loyalty_accrual_rub_amt                                                    NaN
# nominal_price_eur_amt                                                     60,0
# nominal_price_rub_amt                                                   5859,0
# order_item_cnt                                                             1,0
# month_beginning_balance_rub                                             2177,0
# monthly_income_amt                                                     60300,0
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                       1,0
# call_contact_6m_flg                                                        NaN
# call_contact_3m_flg                                                        NaN
# call_contact_1m_flg                                                        NaN
# good_email_address_flg                                                     NaN
# bad_email_address_flg                                                      NaN
# email_valid_flg                                                              1
# children_cnt                                                               0,0
# age                                                                       30,0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                               Саратов
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                          Г САРАТОВ
# lvn_state_nm                                                   САРАТОВСКАЯ ОБЛ
# time_zone_delta_tm                                                    04:00:00
# time_zone_cd                                                                 4
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      MPL
# mobile_phone_operator_nm                                               МегаФон
# marital_status_cd                                                          NaN
# education_level_cd                                                         NaN
# birth_place                                                       ГОР. САРАТОВ
# gender_cd                                                                    F
# last_sms_dt                                                         2024-06-29
# last_email_send_dt                                                         NaN
# last_session_dttm                                   2024-11-06 19:43:31.000000
#
#                                                                         732839  \
# order_online_payment_flg                                                   1,0
# account_rk                   d54845149e52af0220630f090273fd2a92aa5b58d73610...
# client_rk                    962e1fecdf7be1f0c25e67f1f02cbd0723b603d3e0fc1c...
# order_rk                     0e96ce1105dcf265bcda157a54d31701446e0c57444614...
# loyalty_program_type_nm                                  Tinkoff Black Premium
# bundle_nm                                                              Premium
# order_type_cd                                                              AIR
# order_status_cd                                                            SUC
# party_first_order_dt                                                2021-11-26
# party_first_order_type_dt                                           2022-10-28
# free_cancel_booking_dttm                                                   NaN
# created_dttm                                        2024-09-18 20:13:21.553574
# cancel_dttm                                                                NaN
# book_start_dttm                                     2024-09-19 04:00:00.000000
# local_book_start_dttm                               2024-09-19 04:00:00.000000
# book_end_dttm                                                              NaN
# hotel_country                                                              NaN
# hotel_city                                                                 NaN
# avia_dep_city                                                          Стамбул
# avia_arr_city                                                           Москва
# promo_code_discount_amt                                                    0,0
# loyalty_accrual_rub_amt                                                 1435,0
# nominal_price_eur_amt                                                    283,0
# nominal_price_rub_amt                                                  28712,0
# order_item_cnt                                                             2,0
# month_beginning_balance_rub                                            50179,0
# monthly_income_amt                                                    113900,0
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                 15,0
# last_sms_success_flg                                                       1,0
# call_contact_6m_flg                                                        NaN
# call_contact_3m_flg                                                        NaN
# call_contact_1m_flg                                                        NaN
# good_email_address_flg                                                     NaN
# bad_email_address_flg                                                      NaN
# email_valid_flg                                                              1
# children_cnt                                                               0,0
# age                                                                       30,0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                       Санкт-Петербург
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                     Г НОВОРОССИЙСК
# lvn_state_nm                                                КРАСНОДАРСКИЙ КРАЙ
# time_zone_delta_tm                                                    03:00:00
# time_zone_cd                                                                 3
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      MPL
# mobile_phone_operator_nm                                                   МТС
# marital_status_cd                                                          NaN
# education_level_cd                                                         NaN
# birth_place                                   ГОР. ВЛАДИКАВКАЗ СЕВЕРНАЯ ОСЕТИЯ
# gender_cd                                                                    F
# last_sms_dt                                                         2024-07-03
# last_email_send_dt                                                         NaN
# last_session_dttm                                   2024-11-06 20:18:26.000000
#
#                                                                         354230  \
# order_online_payment_flg                                                   1,0
# account_rk                   64da36559574eb2c45e091124d3fcac877c98e7169933b...
# client_rk                    3e93a9a94a676cdb18efca32f0b62d45758ddbbf62d550...
# order_rk                     2e1566e857614a9584ebaf16f4a0db512e2063aacfa907...
# loyalty_program_type_nm                                          Tinkoff Black
# bundle_nm                                                                  NaN
# order_type_cd                                                              HOT
# order_status_cd                                                            SUC
# party_first_order_dt                                                2021-03-26
# party_first_order_type_dt                                           2022-07-28
# free_cancel_booking_dttm                                                   NaN
# created_dttm                                        2024-02-15 16:35:15.108000
# cancel_dttm                                                                NaN
# book_start_dttm                                     2024-02-18 00:00:00.000000
# local_book_start_dttm                               2024-02-18 00:00:00.000000
# book_end_dttm                                       2024-02-20 00:00:00.000000
# hotel_country                                                           Россия
# hotel_city                                                              Ковров
# avia_dep_city                                                              NaN
# avia_arr_city                                                              NaN
# promo_code_discount_amt                                                    NaN
# loyalty_accrual_rub_amt                                                  528,0
# nominal_price_eur_amt                                                     42,0
# nominal_price_rub_amt                                                   4060,0
# order_item_cnt                                                             NaN
# month_beginning_balance_rub                                            87117,0
# monthly_income_amt                                                     50250,0
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                       1,0
# call_contact_6m_flg                                                        NaN
# call_contact_3m_flg                                                        NaN
# call_contact_1m_flg                                                        NaN
# good_email_address_flg                                                     NaN
# bad_email_address_flg                                                      NaN
# email_valid_flg                                                              1
# children_cnt                                                               0,0
# age                                                                       37,0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                                   NaN
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                                NaN
# lvn_state_nm                                                          Г МОСКВА
# time_zone_delta_tm                                                    03:00:00
# time_zone_cd                                                                 3
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      IBN
# mobile_phone_operator_nm                                                   МТС
# marital_status_cd                                                          NaN
# education_level_cd                                                         GRD
# birth_place                                   ГОР. УЛАН-УДЭ РЕСПУБЛИКИ БУРЯТИЯ
# gender_cd                                                                    F
# last_sms_dt                                                         2024-07-03
# last_email_send_dt                                                         NaN
# last_session_dttm                                   2024-11-06 18:45:23.000000
#
#                                                                         302050  \
# order_online_payment_flg                                                   1,0
# account_rk                   1842cb5251b9c58d9f99c295a8761ebdd4c1cad86cac2c...
# client_rk                    df5b43b18a00f21f4e7ea9f746b60af72e61fbff4d0576...
# order_rk                     cc68eebf7903be01f45a684eebe47740f5eee138e744f2...
# loyalty_program_type_nm                                                  Bravo
# bundle_nm                                                                  Pro
# order_type_cd                                                              AIR
# order_status_cd                                                            ERR
# party_first_order_dt                                                2022-08-18
# party_first_order_type_dt                                           2022-08-18
# free_cancel_booking_dttm                                                   NaN
# created_dttm                                        2024-03-07 18:45:26.266189
# cancel_dttm                                                                NaN
# book_start_dttm                                     2024-03-17 14:00:00.000000
# local_book_start_dttm                               2024-03-17 14:00:00.000000
# book_end_dttm                                                              NaN
# hotel_country                                                              NaN
# hotel_city                                                                 NaN
# avia_dep_city                                                          Тбилиси
# avia_arr_city                                                          Ларнака
# promo_code_discount_amt                                                    0,0
# loyalty_accrual_rub_amt                                                    NaN
# nominal_price_eur_amt                                                    734,0
# nominal_price_rub_amt                                                  72061,0
# order_item_cnt                                                             1,0
# month_beginning_balance_rub                                            76027,0
# monthly_income_amt                                                    187600,0
# suppress_email_flg                                                           0
# suppress_call_flg                                                            1
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                       1,0
# call_contact_6m_flg                                                        NaN
# call_contact_3m_flg                                                        NaN
# call_contact_1m_flg                                                        NaN
# good_email_address_flg                                                     NaN
# bad_email_address_flg                                                      NaN
# email_valid_flg                                                              1
# children_cnt                                                               0,0
# age                                                                       34,0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                                   МСК
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                                NaN
# lvn_state_nm                                                          Г МОСКВА
# time_zone_delta_tm                                                    03:00:00
# time_zone_cd                                                                 3
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      MPL
# mobile_phone_operator_nm                                                Билайн
# marital_status_cd                                                          UNM
# education_level_cd                                                         GRD
# birth_place                                                       ГОРОД МОСКВА
# gender_cd                                                                    F
# last_sms_dt                                                         2024-06-20
# last_email_send_dt                                                         NaN
# last_session_dttm                                   2024-11-02 12:22:22.000000
#
#                                                                         674816  \
# order_online_payment_flg                                                   NaN
# account_rk                   9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6...
# client_rk                    96e49067301f1bf2903ef18543cb35d0f35e44697764ef...
# order_rk                     9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6...
# loyalty_program_type_nm                                                    NaN
# bundle_nm                                                                  NaN
# order_type_cd                                                              NaN
# order_status_cd                                                            NaN
# party_first_order_dt                                                       NaN
# party_first_order_type_dt                                                  NaN
# free_cancel_booking_dttm                                                   NaN
# created_dttm                                                               NaN
# cancel_dttm                                                                NaN
# book_start_dttm                                                            NaN
# local_book_start_dttm                                                      NaN
# book_end_dttm                                                              NaN
# hotel_country                                                              NaN
# hotel_city                                                                 NaN
# avia_dep_city                                                              NaN
# avia_arr_city                                                              NaN
# promo_code_discount_amt                                                    NaN
# loyalty_accrual_rub_amt                                                    NaN
# nominal_price_eur_amt                                                      NaN
# nominal_price_rub_amt                                                      NaN
# order_item_cnt                                                             NaN
# month_beginning_balance_rub                                                NaN
# monthly_income_amt                                                    167500,0
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                       0,0
# call_contact_6m_flg                                                        NaN
# call_contact_3m_flg                                                        NaN
# call_contact_1m_flg                                                        NaN
# good_email_address_flg                                                     NaN
# bad_email_address_flg                                                      NaN
# email_valid_flg                                                              1
# children_cnt                                                               0,0
# age                                                                       26,0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                       Санкт-Петербург
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                                NaN
# lvn_state_nm                                                 Г САНКТ-ПЕТЕРБУРГ
# time_zone_delta_tm                                                    03:00:00
# time_zone_cd                                                                 3
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      MPL
# mobile_phone_operator_nm                                               МегаФон
# marital_status_cd                                                          UNM
# education_level_cd                                                         GRD
# birth_place                                               ГОР. САНКТ-ПЕТЕРБУРГ
# gender_cd                                                                    F
# last_sms_dt                                                         2024-09-21
# last_email_send_dt                                                         NaN
# last_session_dttm                                   2024-11-06 21:10:44.000000
#
#                                                                         712731  \
# order_online_payment_flg                                                   1,0
# account_rk                   887481114e9ded784a21fff94a4a67a533c9054016ecb5...
# client_rk                    0ed0126c02b601029b03d0d13cd9def3b5af4592bc40b2...
# order_rk                     fca32cfe8d60a650629055c8f4370aeeea580d2a4a0845...
# loyalty_program_type_nm                                  Tinkoff Black Premium
# bundle_nm                                                              Premium
# order_type_cd                                                              AIR
# order_status_cd                                                            SUC
# party_first_order_dt                                                2022-02-08
# party_first_order_type_dt                                           2022-02-08
# free_cancel_booking_dttm                                                   NaN
# created_dttm                                        2024-08-11 20:27:22.174385
# cancel_dttm                                                                NaN
# book_start_dttm                                     2024-08-22 16:00:00.000000
# local_book_start_dttm                               2024-08-22 16:00:00.000000
# book_end_dttm                                                              NaN
# hotel_country                                                              NaN
# hotel_city                                                                 NaN
# avia_dep_city                                                           Москва
# avia_arr_city                                                  Санкт-Петербург
# promo_code_discount_amt                                                    0,0
# loyalty_accrual_rub_amt                                                  212,0
# nominal_price_eur_amt                                                     45,0
# nominal_price_rub_amt                                                   4242,0
# order_item_cnt                                                             1,0
# month_beginning_balance_rub                                              373,0
# monthly_income_amt                                                    100500,0
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                       1,0
# call_contact_6m_flg                                                        NaN
# call_contact_3m_flg                                                        NaN
# call_contact_1m_flg                                                        NaN
# good_email_address_flg                                                     NaN
# bad_email_address_flg                                                      NaN
# email_valid_flg                                                              1
# children_cnt                                                               0,0
# age                                                                       29,0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                                   МСК
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                           Г МОСКВА
# lvn_state_nm                                                          Г МОСКВА
# time_zone_delta_tm                                                    04:00:00
# time_zone_cd                                                                 4
# last_used_product_cd                                                       INV
# first_used_product_cd                                                      IPL
# mobile_phone_operator_nm                                               МегаФон
# marital_status_cd                                                          MAR
# education_level_cd                                                         GRD
# birth_place                                        ГОР. ТОЛЬЯТТИ САМАРСКОЙ ОБЛ
# gender_cd                                                                    F
# last_sms_dt                                                         2024-07-03
# last_email_send_dt                                                         NaN
# last_session_dttm                                   2024-11-06 23:58:44.000000
#
#                                                                         444593
# order_online_payment_flg                                                   1,0
# account_rk                   9dbb79581996977041708ee873e4ea4cef202c1d403d18...
# client_rk                    4894fd2ee14cc7b6cebf8f610f95aae056ce698f92735f...
# order_rk                     0b49e8f37483d79b9494cb019bc26183092fdb992e33d9...
# loyalty_program_type_nm                                          Tinkoff Black
# bundle_nm                                                                  Pro
# order_type_cd                                                              HOT
# order_status_cd                                                            NaN
# party_first_order_dt                                                2019-02-14
# party_first_order_type_dt                                           2023-07-10
# free_cancel_booking_dttm                            2024-06-14 11:00:00.000000
# created_dttm                                        2024-05-28 22:32:06.091000
# cancel_dttm                                                                NaN
# book_start_dttm                                     2024-06-15 00:00:00.000000
# local_book_start_dttm                               2024-06-15 00:00:00.000000
# book_end_dttm                                       2024-06-16 00:00:00.000000
# hotel_country                                                              NaN
# hotel_city                                                                 NaN
# avia_dep_city                                                              NaN
# avia_arr_city                                                              NaN
# promo_code_discount_amt                                                    NaN
# loyalty_accrual_rub_amt                                                    NaN
# nominal_price_eur_amt                                                     41,0
# nominal_price_rub_amt                                                   3953,0
# order_item_cnt                                                             NaN
# month_beginning_balance_rub                                            42689,0
# monthly_income_amt                                                         NaN
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                       0,0
# call_contact_6m_flg                                                        NaN
# call_contact_3m_flg                                                        NaN
# call_contact_1m_flg                                                        NaN
# good_email_address_flg                                                     1,0
# bad_email_address_flg                                                      0,0
# email_valid_flg                                                              1
# children_cnt                                                               0,0
# age                                                                       46,0
# age_type_cd                                                                A40
# parent_meeting_region_nm                                                   NaN
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                                NaN
# lvn_state_nm                                                          Г МОСКВА
# time_zone_delta_tm                                                    03:00:00
# time_zone_cd                                                                 3
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      IBN
# mobile_phone_operator_nm                                                Билайн
# marital_status_cd                                                          NaN
# education_level_cd                                                         NaN
# birth_place                                                        Г ВОЛГОГРАД
# gender_cd                                                                    M
# last_sms_dt                                                         2024-09-27
# last_email_send_dt                                                  2012-04-09
# last_session_dttm                                   2024-11-06 22:51:28.000000

# %% [markdown]
# # Убираем пробельные символы по бокам и заменяем все текстовые аналоги NaN. Также создаём резрвную копию df, чтобы потом не пришлось заново читать её из файла

# %%
df_backup_copy = df.copy(deep=True)

# %%
df = df_backup_copy.copy(deep=True)

# %%
for col in df.columns: 
    df[col] = df[col].map(lambda x: x.strip() if isinstance(x, str) else x)


list_str_nan = ["", " ", "-", "—", "NaN", "nan", "NULL", "None", "N/A"]
df.replace(list_str_nan, pd.NA, inplace=True)

# %% [markdown]
# # Приводим данные к нужным типам

# %% [markdown]
# - 27  suppress_email_flg —           835938 non-null  int64
# - 28  suppress_call_flg —            835938 non-null  int64
# - 29  bounce_cd —                    39675 non-null   object
# - 30  last_sms_success_flg —         833939 non-null  object
# - 31  call_contact_6m_flg —          271 non-null     object
# - 32  call_contact_3m_flg —          271 non-null     object
# - 33  call_contact_1m_flg —          271 non-null     object
# - 34  good_email_address_flg —       19798 non-null   object
# - 35  bad_email_address_flg —        19798 non-null   object
# - 36  email_valid_flg —              835938 non-null  int64

# %%
num_cols = ["promo_code_discount_amt", "nominal_price_eur_amt", "loyalty_accrual_rub_amt", "nominal_price_rub_amt", "order_item_cnt", 
            "month_beginning_balance_rub", "monthly_income_amt", "children_cnt", "age", "time_zone_cd"]

for i in num_cols:
    df[i] = df[i].str.replace(",", ".")
    df[i] = pd.to_numeric(df[i], errors="coerce")

# %%
date_cols = ["party_first_order_dt", "party_first_order_type_dt", "party_first_order_type_dt", "free_cancel_booking_dttm", "created_dttm",
             "book_start_dttm", "local_book_start_dttm", "book_end_dttm", "last_sms_dt", "last_email_send_dt", "last_session_dttm"]

for i in date_cols:
    df[i] = pd.to_datetime(df[i], errors="coerce")

# %%
date_fg = ["order_online_payment_flg", "last_sms_success_flg", "call_contact_6m_flg", "call_contact_3m_flg", "call_contact_1m_flg",
           "good_email_address_flg", "bad_email_address_flg"] # Исключая suppress_email_flg, suppress_call_flg и email_valid_flg (потому что они int)

for i in date_fg:
    df[i] = df[i].str.replace(",", ".")
    df[i] = pd.to_numeric(df[i], errors="coerce").astype("Int64")

# %% [markdown]
# # Повторный беглый просмотр данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 835938 entries, 0 to 835937
# Data columns (total 56 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   order_online_payment_flg     786885 non-null  Int64
#  1   account_rk                   835938 non-null  object
#  2   client_rk                    835938 non-null  object
#  3   order_rk                     835938 non-null  object
#  4   loyalty_program_type_nm      754957 non-null  object
#  5   bundle_nm                    588049 non-null  object
#  6   order_type_cd                786885 non-null  object
#  7   order_status_cd              779514 non-null  object
#  8   party_first_order_dt         786885 non-null  datetime64[ns]
#  9   party_first_order_type_dt    786767 non-null  datetime64[ns]
#  10  free_cancel_booking_dttm     75600 non-null   datetime64[ns]
#  11  created_dttm                 786885 non-null  datetime64[ns]
#  12  cancel_dttm                  0 non-null       float64
#  13  book_start_dttm              786885 non-null  datetime64[ns]
#  14  local_book_start_dttm        786885 non-null  datetime64[ns]
#  15  book_end_dttm                171548 non-null  datetime64[ns]
#  16  hotel_country                162248 non-null  object
#  17  hotel_city                   162248 non-null  object
#  18  avia_dep_city                615275 non-null  object
#  19  avia_arr_city                615275 non-null  object
#  20  promo_code_discount_amt      615900 non-null  float64
#  21  loyalty_accrual_rub_amt      475353 non-null  float64
#  22  nominal_price_eur_amt        786885 non-null  float64
#  23  nominal_price_rub_amt        786885 non-null  float64
#  24  order_item_cnt               615337 non-null  float64
#  25  month_beginning_balance_rub  776628 non-null  float64
#  26  monthly_income_amt           673078 non-null  float64
#  27  suppress_email_flg           835938 non-null  int64
#  28  suppress_call_flg            835938 non-null  int64
#  29  bounce_cd                    39675 non-null   object
#  30  last_sms_success_flg         833939 non-null  Int64
#  31  call_contact_6m_flg          271 non-null     Int64
#  32  call_contact_3m_flg          271 non-null     Int64
#  33  call_contact_1m_flg          271 non-null     Int64
#  34  good_email_address_flg       19798 non-null   Int64
#  35  bad_email_address_flg        19798 non-null   Int64
#  36  email_valid_flg              835938 non-null  int64
#  37  children_cnt                 719699 non-null  float64
#  38  age                          835937 non-null  float64
#  39  age_type_cd                  835690 non-null  object
#  40  parent_meeting_region_nm     786457 non-null  object
#  41  delivery_region_category_cd  835938 non-null  object
#  42  lvn_city_nm                  475969 non-null  object
#  43  lvn_state_nm                 783169 non-null  object
#  44  time_zone_delta_tm           835938 non-null  object
#  45  time_zone_cd                 196596 non-null  float64
#  46  last_used_product_cd         835935 non-null  object
#  47  first_used_product_cd        833478 non-null  object
#  48  mobile_phone_operator_nm     834698 non-null  object
#  49  marital_status_cd            520888 non-null  object
#  50  education_level_cd           475104 non-null  object
#  51  birth_place                  832851 non-null  object
#  52  gender_cd                    825781 non-null  object
#  53  last_sms_dt                  833939 non-null  datetime64[ns]
#  54  last_email_send_dt           19798 non-null   datetime64[ns]
#  55  last_session_dttm            835938 non-null  datetime64[ns]
# dtypes: Int64(7), datetime64[ns](10), float64(11), int64(3), object(25)
# memory usage: 362.7+ MB

# %%
df.sample(10).T
# Out:
#                                                                         71001   \
# order_online_payment_flg                                                     1
# account_rk                   d563f3123ea48cfb331479bb88fedde6be4dc74e728c28...
# client_rk                    d69420f6a29c727f7576e2c6575c734984a7806c8067c4...
# order_rk                     1941ee1f07de0f2233d087c17890831a9178eb21e566a3...
# loyalty_program_type_nm                                  Tinkoff Black Premium
# bundle_nm                                                              Premium
# order_type_cd                                                              HOT
# order_status_cd                                                            SUC
# party_first_order_dt                                       2023-01-14 00:00:00
# party_first_order_type_dt                                  2023-01-19 00:00:00
# free_cancel_booking_dttm                                   2024-10-26 00:00:00
# created_dttm                                        2024-10-24 06:59:35.598000
# cancel_dttm                                                                NaN
# book_start_dttm                                            2024-10-26 00:00:00
# local_book_start_dttm                                      2024-10-26 00:00:00
# book_end_dttm                                              2024-10-27 00:00:00
# hotel_country                                                           Россия
# hotel_city                                                              Москва
# avia_dep_city                                                              NaN
# avia_arr_city                                                              NaN
# promo_code_discount_amt                                                    NaN
# loyalty_accrual_rub_amt                                                  878.0
# nominal_price_eur_amt                                                     84.0
# nominal_price_rub_amt                                                   8777.0
# order_item_cnt                                                             NaN
# month_beginning_balance_rub                                             6242.0
# monthly_income_amt                                                    261300.0
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                         1
# call_contact_6m_flg                                                       <NA>
# call_contact_3m_flg                                                       <NA>
# call_contact_1m_flg                                                       <NA>
# good_email_address_flg                                                    <NA>
# bad_email_address_flg                                                     <NA>
# email_valid_flg                                                              1
# children_cnt                                                               2.0
# age                                                                       39.0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                          Екатеринбург
# delivery_region_category_cd                                                GRE
# lvn_city_nm                                                                NaN
# lvn_state_nm                                                    КУРГАНСКАЯ ОБЛ
# time_zone_delta_tm                                                    05:00:00
# time_zone_cd                                                               NaN
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      MPL
# mobile_phone_operator_nm                                                   МТС
# marital_status_cd                                                          UNM
# education_level_cd                                                         GRD
# birth_place                  С. КАЛТАР СОКУЛУКСКОГО Р-НА КИРГИЗСКОЙ РЕСПУБЛИКИ
# gender_cd                                                                    M
# last_sms_dt                                                2024-08-31 00:00:00
# last_email_send_dt                                                         NaT
# last_session_dttm                                          2024-11-06 09:54:50
#
#                                                                         431290  \
# order_online_payment_flg                                                     1
# account_rk                   326ee4d94d488ea26a2d85625b7a96ffd144471a4ed623...
# client_rk                    d0b69571226dc565192a2ba35d6fed8a59b3fbf404d2b3...
# order_rk                     77b89dc159c893d0f4f99f6e5ced3f742a1829cb1778f9...
# loyalty_program_type_nm                                          Tinkoff Black
# bundle_nm                                                                  Pro
# order_type_cd                                                              AIR
# order_status_cd                                                            SUC
# party_first_order_dt                                       2022-04-17 00:00:00
# party_first_order_type_dt                                  2022-05-09 00:00:00
# free_cancel_booking_dttm                                                   NaT
# created_dttm                                        2024-01-29 19:15:53.267578
# cancel_dttm                                                                NaN
# book_start_dttm                                            2024-02-01 06:35:00
# local_book_start_dttm                                      2024-02-01 06:35:00
# book_end_dttm                                                              NaT
# hotel_country                                                              NaN
# hotel_city                                                                 NaN
# avia_dep_city                                                           Москва
# avia_arr_city                                                      Калининград
# promo_code_discount_amt                                                    0.0
# loyalty_accrual_rub_amt                                                  429.0
# nominal_price_eur_amt                                                     88.0
# nominal_price_rub_amt                                                   8576.0
# order_item_cnt                                                             2.0
# month_beginning_balance_rub                                            14598.0
# monthly_income_amt                                                     93800.0
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                         1
# call_contact_6m_flg                                                       <NA>
# call_contact_3m_flg                                                       <NA>
# call_contact_1m_flg                                                       <NA>
# good_email_address_flg                                                    <NA>
# bad_email_address_flg                                                     <NA>
# email_valid_flg                                                              1
# children_cnt                                                               0.0
# age                                                                       29.0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                                   МСК
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                         Г КАСПИЙСК
# lvn_state_nm                                                     РЕСП ДАГЕСТАН
# time_zone_delta_tm                                                    03:00:00
# time_zone_cd                                                               NaN
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      INV
# mobile_phone_operator_nm                                                Билайн
# marital_status_cd                                                          NaN
# education_level_cd                                                         NaN
# birth_place                                   ГОР КАСПИЙСК РЕСПУБЛИКА ДАГЕСТАН
# gender_cd                                                                    M
# last_sms_dt                                                2024-06-25 00:00:00
# last_email_send_dt                                                         NaT
# last_session_dttm                                          2024-10-29 22:12:44
#
#                                                                         101808  \
# order_online_payment_flg                                                     1
# account_rk                   9f0622b3fa7197d34b52f6db6bad2d4039263e207c28a1...
# client_rk                    96c1d0f5a9d9ce26aa77640aeff9adf0200d9be4fab9fe...
# order_rk                     4e0608f027b5ea794d18989f5b514f119364bd1153749d...
# loyalty_program_type_nm                                          Tinkoff Black
# bundle_nm                                                                  Pro
# order_type_cd                                                              HOT
# order_status_cd                                                            SUC
# party_first_order_dt                                       2019-10-18 00:00:00
# party_first_order_type_dt                                  2020-02-09 00:00:00
# free_cancel_booking_dttm                                                   NaT
# created_dttm                                        2024-08-02 18:36:07.692000
# cancel_dttm                                                                NaN
# book_start_dttm                                            2024-08-03 00:00:00
# local_book_start_dttm                                      2024-08-03 00:00:00
# book_end_dttm                                              2024-08-04 00:00:00
# hotel_country                                                           Россия
# hotel_city                                                                 Уфа
# avia_dep_city                                                              NaN
# avia_arr_city                                                              NaN
# promo_code_discount_amt                                                    NaN
# loyalty_accrual_rub_amt                                                    NaN
# nominal_price_eur_amt                                                     22.0
# nominal_price_rub_amt                                                   2080.0
# order_item_cnt                                                             NaN
# month_beginning_balance_rub                                            11400.0
# monthly_income_amt                                                         NaN
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                         1
# call_contact_6m_flg                                                       <NA>
# call_contact_3m_flg                                                       <NA>
# call_contact_1m_flg                                                       <NA>
# good_email_address_flg                                                    <NA>
# bad_email_address_flg                                                     <NA>
# email_valid_flg                                                              1
# children_cnt                                                               0.0
# age                                                                       42.0
# age_type_cd                                                                A40
# parent_meeting_region_nm                                          Невинномысск
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                     Г НЕВИННОМЫССК
# lvn_state_nm                                               СТАВРОПОЛЬСКИЙ КРАЙ
# time_zone_delta_tm                                                    03:00:00
# time_zone_cd                                                               3.0
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      MPL
# mobile_phone_operator_nm                                                Билайн
# marital_status_cd                                                          NaN
# education_level_cd                                                         NaN
# birth_place                                           ГОР. ОРДЖОНИКИДЗЕ СОАССР
# gender_cd                                                                    M
# last_sms_dt                                                2024-07-03 00:00:00
# last_email_send_dt                                                         NaT
# last_session_dttm                                          2024-11-06 17:55:21
#
#                                                                         58742   \
# order_online_payment_flg                                                     1
# account_rk                   10356df17d571a628cdc5e715e25c9fffc7c1c418aeb9b...
# client_rk                    6ec98318286b56dfb764638739927578734ec8faf2c661...
# order_rk                     cd12cff6c28eb2c47849af0c58226250f821703e7a1875...
# loyalty_program_type_nm                                  Tinkoff Black Premium
# bundle_nm                                                              Premium
# order_type_cd                                                              AIR
# order_status_cd                                                            SUC
# party_first_order_dt                                       2023-05-06 00:00:00
# party_first_order_type_dt                                  2023-05-06 00:00:00
# free_cancel_booking_dttm                                                   NaT
# created_dttm                                        2024-06-29 01:11:59.380646
# cancel_dttm                                                                NaN
# book_start_dttm                                            2024-07-01 19:30:00
# local_book_start_dttm                                      2024-07-01 19:30:00
# book_end_dttm                                                              NaT
# hotel_country                                                              NaN
# hotel_city                                                                 NaN
# avia_dep_city                                                           Москва
# avia_arr_city                                                           Ереван
# promo_code_discount_amt                                                    0.0
# loyalty_accrual_rub_amt                                                 1809.0
# nominal_price_eur_amt                                                    392.0
# nominal_price_rub_amt                                                  36191.0
# order_item_cnt                                                             2.0
# month_beginning_balance_rub                                            26972.0
# monthly_income_amt                                                    636500.0
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                         1
# call_contact_6m_flg                                                       <NA>
# call_contact_3m_flg                                                       <NA>
# call_contact_1m_flg                                                       <NA>
# good_email_address_flg                                                    <NA>
# bad_email_address_flg                                                     <NA>
# email_valid_flg                                                              1
# children_cnt                                                               0.0
# age                                                                       36.0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                             ЛО Восток
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                                NaN
# lvn_state_nm                                                 Г САНКТ-ПЕТЕРБУРГ
# time_zone_delta_tm                                                    03:00:00
# time_zone_cd                                                               3.0
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      INV
# mobile_phone_operator_nm                                                 TELE2
# marital_status_cd                                                          NaN
# education_level_cd                                                         NaN
# birth_place                                                      ГОР ЛЕНИНГРАД
# gender_cd                                                                    M
# last_sms_dt                                                2024-07-01 00:00:00
# last_email_send_dt                                                         NaT
# last_session_dttm                                          2024-11-04 13:01:57
#
#                                                                         451241  \
# order_online_payment_flg                                                     1
# account_rk                   bd21fa8fd9f8b328f1be2a800e24d183b070f72be75fcb...
# client_rk                    2af019ecc5603de1b942b3ddbddc1ea2da1ce00d5997a1...
# order_rk                     c14fb10ce8771c393882cdfae1aabcc116f50b88c37859...
# loyalty_program_type_nm                                                  Bravo
# bundle_nm                                                              Premium
# order_type_cd                                                              AIR
# order_status_cd                                                            SUC
# party_first_order_dt                                       2022-07-20 00:00:00
# party_first_order_type_dt                                  2023-01-09 00:00:00
# free_cancel_booking_dttm                                                   NaT
# created_dttm                                        2024-09-26 11:47:42.192960
# cancel_dttm                                                                NaN
# book_start_dttm                                            2024-09-27 14:20:00
# local_book_start_dttm                                      2024-09-27 14:20:00
# book_end_dttm                                                              NaT
# hotel_country                                                              NaN
# hotel_city                                                                 NaN
# avia_dep_city                                                        Хабаровск
# avia_arr_city                                                       Красноярск
# promo_code_discount_amt                                                    0.0
# loyalty_accrual_rub_amt                                                    NaN
# nominal_price_eur_amt                                                    220.0
# nominal_price_rub_amt                                                  22717.0
# order_item_cnt                                                             2.0
# month_beginning_balance_rub                                              676.0
# monthly_income_amt                                                    234500.0
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                         0
# call_contact_6m_flg                                                       <NA>
# call_contact_3m_flg                                                       <NA>
# call_contact_1m_flg                                                       <NA>
# good_email_address_flg                                                    <NA>
# bad_email_address_flg                                                     <NA>
# email_valid_flg                                                              1
# children_cnt                                                               0.0
# age                                                                       32.0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                                Тюмень
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                           Г ТЮМЕНЬ
# lvn_state_nm                                                     ТЮМЕНСКАЯ ОБЛ
# time_zone_delta_tm                                                    05:00:00
# time_zone_cd                                                               NaN
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      MPL
# mobile_phone_operator_nm                                               МегаФон
# marital_status_cd                                                          MAR
# education_level_cd                                                         GRD
# birth_place                                                        ГОР. ТЮМЕНЬ
# gender_cd                                                                    M
# last_sms_dt                                                2024-11-02 00:00:00
# last_email_send_dt                                                         NaT
# last_session_dttm                                          2024-11-06 19:07:18
#
#                                                                         396459  \
# order_online_payment_flg                                                     1
# account_rk                   33dfb602de6e7c2b2e99d8e863a67266204692700111c0...
# client_rk                    dcf9bf5a817bce350ea6557aa21971a5880c417693c639...
# order_rk                     2270501f8b196104e50a2e186e2874887bb9379b25d788...
# loyalty_program_type_nm                                          Tinkoff Black
# bundle_nm                                                                  NaN
# order_type_cd                                                              HOT
# order_status_cd                                                            SUC
# party_first_order_dt                                       2024-05-15 00:00:00
# party_first_order_type_dt                                  2024-05-15 00:00:00
# free_cancel_booking_dttm                                                   NaT
# created_dttm                                        2024-06-09 12:23:20.850000
# cancel_dttm                                                                NaN
# book_start_dttm                                            2024-06-16 00:00:00
# local_book_start_dttm                                      2024-06-16 00:00:00
# book_end_dttm                                              2024-06-19 00:00:00
# hotel_country                                                           Россия
# hotel_city                                                     Санкт-Петербург
# avia_dep_city                                                              NaN
# avia_arr_city                                                              NaN
# promo_code_discount_amt                                                    NaN
# loyalty_accrual_rub_amt                                                 1340.0
# nominal_price_eur_amt                                                    159.0
# nominal_price_rub_amt                                                  15377.0
# order_item_cnt                                                             NaN
# month_beginning_balance_rub                                               15.0
# monthly_income_amt                                                         NaN
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                         1
# call_contact_6m_flg                                                       <NA>
# call_contact_3m_flg                                                       <NA>
# call_contact_1m_flg                                                       <NA>
# good_email_address_flg                                                    <NA>
# bad_email_address_flg                                                     <NA>
# email_valid_flg                                                              1
# children_cnt                                                               NaN
# age                                                                       26.0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                   Москва Зеленая Верх
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                                NaN
# lvn_state_nm                                                          Г МОСКВА
# time_zone_delta_tm                                                    03:00:00
# time_zone_cd                                                               NaN
# last_used_product_cd                                                       IPL
# first_used_product_cd                                                      IPL
# mobile_phone_operator_nm                                       Тинькофф Мобайл
# marital_status_cd                                                          NaN
# education_level_cd                                                         NaN
# birth_place                                                           ZHEJIANG
# gender_cd                                                                    M
# last_sms_dt                                                2024-07-31 00:00:00
# last_email_send_dt                                                         NaT
# last_session_dttm                                          2024-10-29 08:23:28
#
#                                                                         656620  \
# order_online_payment_flg                                                     1
# account_rk                   42405f81b4e9d8c3f8d9a740a3f16e7793c80bb11fcf38...
# client_rk                    beb6be69023a4d273fac9a86f29f1827a42c8f0f653e21...
# order_rk                     cf3dc34f3a493cbbef59692c764f1c1d44f04922e87213...
# loyalty_program_type_nm                                                  Bravo
# bundle_nm                                                                  Pro
# order_type_cd                                                              AIR
# order_status_cd                                                            SUC
# party_first_order_dt                                       2023-06-21 00:00:00
# party_first_order_type_dt                                  2023-06-21 00:00:00
# free_cancel_booking_dttm                                                   NaT
# created_dttm                                        2024-03-04 20:47:13.124011
# cancel_dttm                                                                NaN
# book_start_dttm                                            2024-03-06 04:15:00
# local_book_start_dttm                                      2024-03-06 04:15:00
# book_end_dttm                                                              NaT
# hotel_country                                                              NaN
# hotel_city                                                                 NaN
# avia_dep_city                                                     Екатеринбург
# avia_arr_city                                                     Сочи (Адлер)
# promo_code_discount_amt                                                    0.0
# loyalty_accrual_rub_amt                                                    NaN
# nominal_price_eur_amt                                                    266.0
# nominal_price_rub_amt                                                  26286.0
# order_item_cnt                                                             3.0
# month_beginning_balance_rub                                             6427.0
# monthly_income_amt                                                   1005000.0
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                         0
# call_contact_6m_flg                                                       <NA>
# call_contact_3m_flg                                                       <NA>
# call_contact_1m_flg                                                       <NA>
# good_email_address_flg                                                    <NA>
# bad_email_address_flg                                                     <NA>
# email_valid_flg                                                              1
# children_cnt                                                               0.0
# age                                                                       34.0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                          Екатеринбург
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                     Г ЕКАТЕРИНБУРГ
# lvn_state_nm                                                  СВЕРДЛОВСКАЯ ОБЛ
# time_zone_delta_tm                                                    05:00:00
# time_zone_cd                                                               NaN
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      IBN
# mobile_phone_operator_nm                                               МегаФон
# marital_status_cd                                                          MAR
# education_level_cd                                                         SCH
# birth_place                                      ГОР. ВОТКИНСК УДМУРТСКОЙ АССР
# gender_cd                                                                    F
# last_sms_dt                                                2024-09-17 00:00:00
# last_email_send_dt                                                         NaT
# last_session_dttm                                          2024-11-06 17:44:52
#
#                                                                         209531  \
# order_online_payment_flg                                                     1
# account_rk                   6cf28d14fc187112b42cc915f2ee3872ad1a7b2248f009...
# client_rk                    996c8d5a82eeae994c0aa5e7fc85cfbcb9532c855fe025...
# order_rk                     950ea81d4ab09896d7ee20aa5bf2e5c89602b96c757b08...
# loyalty_program_type_nm                                  Tinkoff Black Premium
# bundle_nm                                                              Premium
# order_type_cd                                                              AIR
# order_status_cd                                                            SUC
# party_first_order_dt                                       2022-12-19 00:00:00
# party_first_order_type_dt                                  2024-01-18 00:00:00
# free_cancel_booking_dttm                                                   NaT
# created_dttm                                        2024-03-25 23:45:28.882034
# cancel_dttm                                                                NaN
# book_start_dttm                                            2024-04-02 08:35:00
# local_book_start_dttm                                      2024-04-02 08:35:00
# book_end_dttm                                                              NaT
# hotel_country                                                              NaN
# hotel_city                                                                 NaN
# avia_dep_city                                                  Санкт-Петербург
# avia_arr_city                                                           Москва
# promo_code_discount_amt                                                    0.0
# loyalty_accrual_rub_amt                                                  234.0
# nominal_price_eur_amt                                                     47.0
# nominal_price_rub_amt                                                   4702.0
# order_item_cnt                                                             1.0
# month_beginning_balance_rub                                             5092.0
# monthly_income_amt                                                         NaN
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                         1
# call_contact_6m_flg                                                       <NA>
# call_contact_3m_flg                                                       <NA>
# call_contact_1m_flg                                                       <NA>
# good_email_address_flg                                                    <NA>
# bad_email_address_flg                                                     <NA>
# email_valid_flg                                                              1
# children_cnt                                                               0.0
# age                                                                       42.0
# age_type_cd                                                                A40
# parent_meeting_region_nm                                                   МСК
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                      Г АРХАНГЕЛЬСК
# lvn_state_nm                                                 АРХАНГЕЛЬСКАЯ ОБЛ
# time_zone_delta_tm                                                    03:00:00
# time_zone_cd                                                               3.0
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      MPL
# mobile_phone_operator_nm                                                   МТС
# marital_status_cd                                                          NaN
# education_level_cd                                                         NaN
# birth_place                                ГОРОД КЕРЧЬ РЕСПУБЛИКА КРЫМ УКРАИНА
# gender_cd                                                                    M
# last_sms_dt                                                2024-06-27 00:00:00
# last_email_send_dt                                                         NaT
# last_session_dttm                                          2024-11-05 12:36:51
#
#                                                                         20719   \
# order_online_payment_flg                                                     1
# account_rk                   c6b6e0cc7f226dd9d3d2c513d0e1634b85a520a6f702da...
# client_rk                    4db5e05873cf5099112ea6afd99400ace4df1a2e6559a1...
# order_rk                     db0c00d565c9dc8e8a0741503adbf7f30cf2039a62f0a0...
# loyalty_program_type_nm                                          Tinkoff Black
# bundle_nm                                                              Premium
# order_type_cd                                                              AIR
# order_status_cd                                                            SUC
# party_first_order_dt                                       2022-08-07 00:00:00
# party_first_order_type_dt                                  2022-08-07 00:00:00
# free_cancel_booking_dttm                                                   NaT
# created_dttm                                        2024-09-21 18:47:23.486708
# cancel_dttm                                                                NaN
# book_start_dttm                                            2024-09-26 04:00:00
# local_book_start_dttm                                      2024-09-26 04:00:00
# book_end_dttm                                                              NaT
# hotel_country                                                              NaN
# hotel_city                                                                 NaN
# avia_dep_city                                                        Челябинск
# avia_arr_city                                                           Москва
# promo_code_discount_amt                                                  335.0
# loyalty_accrual_rub_amt                                                  115.0
# nominal_price_eur_amt                                                     22.0
# nominal_price_rub_amt                                                   2312.0
# order_item_cnt                                                             1.0
# month_beginning_balance_rub                                              804.0
# monthly_income_amt                                                     87100.0
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                         1
# call_contact_6m_flg                                                       <NA>
# call_contact_3m_flg                                                       <NA>
# call_contact_1m_flg                                                       <NA>
# good_email_address_flg                                                    <NA>
# bad_email_address_flg                                                     <NA>
# email_valid_flg                                                              1
# children_cnt                                                               0.0
# age                                                                       44.0
# age_type_cd                                                                A40
# parent_meeting_region_nm                                             Челябинск
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                                NaN
# lvn_state_nm                                                               NaN
# time_zone_delta_tm                                                    05:00:00
# time_zone_cd                                                               5.0
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      MPL
# mobile_phone_operator_nm                                               МегаФон
# marital_status_cd                                                          NaN
# education_level_cd                                                         NaN
# birth_place                                                    ГОРОД ЧЕЛЯБИНСК
# gender_cd                                                                    M
# last_sms_dt                                                2024-06-19 00:00:00
# last_email_send_dt                                                         NaT
# last_session_dttm                                          2024-11-06 20:35:18
#
#                                                                         746178
# order_online_payment_flg                                                     1
# account_rk                   5eb100e7b69351e495372f2961b4c09fbee40409b97ff3...
# client_rk                    1ec27ffd4a0e1096e2282ddfede4c9d5e0367b0879bf45...
# order_rk                     77d5c7ffdc15c634a1336a273493573cc9c8065f0e6579...
# loyalty_program_type_nm                                  Tinkoff Black Premium
# bundle_nm                                                              Premium
# order_type_cd                                                              HOT
# order_status_cd                                                            SUC
# party_first_order_dt                                       2018-11-13 00:00:00
# party_first_order_type_dt                                  2019-12-11 00:00:00
# free_cancel_booking_dttm                                   2024-05-12 11:00:00
# created_dttm                                        2024-05-11 15:24:18.699000
# cancel_dttm                                                                NaN
# book_start_dttm                                            2024-05-12 00:00:00
# local_book_start_dttm                                      2024-05-12 00:00:00
# book_end_dttm                                              2024-05-13 00:00:00
# hotel_country                                                         Беларусь
# hotel_city                                                               Минск
# avia_dep_city                                                              NaN
# avia_arr_city                                                              NaN
# promo_code_discount_amt                                                    NaN
# loyalty_accrual_rub_amt                                                   52.0
# nominal_price_eur_amt                                                     53.0
# nominal_price_rub_amt                                                   5286.0
# order_item_cnt                                                             NaN
# month_beginning_balance_rub                                             1373.0
# monthly_income_amt                                                         0.0
# suppress_email_flg                                                           0
# suppress_call_flg                                                            0
# bounce_cd                                                                  NaN
# last_sms_success_flg                                                         1
# call_contact_6m_flg                                                       <NA>
# call_contact_3m_flg                                                       <NA>
# call_contact_1m_flg                                                       <NA>
# good_email_address_flg                                                       1
# bad_email_address_flg                                                        0
# email_valid_flg                                                              1
# children_cnt                                                               NaN
# age                                                                       38.0
# age_type_cd                                                                A20
# parent_meeting_region_nm                                                   NaN
# delivery_region_category_cd                                                CIT
# lvn_city_nm                                                                NaN
# lvn_state_nm                                                            МОСКВА
# time_zone_delta_tm                                                    03:00:00
# time_zone_cd                                                               NaN
# last_used_product_cd                                                       MPL
# first_used_product_cd                                                      IBN
# mobile_phone_operator_nm                                                Билайн
# marital_status_cd                                                          NaN
# education_level_cd                                                         NaN
# birth_place                                                             МОСКВА
# gender_cd                                                                    M
# last_sms_dt                                                2024-06-30 00:00:00
# last_email_send_dt                                         2012-04-19 00:00:00
# last_session_dttm                                          2024-11-04 19:08:41

# %% [markdown]
# # Функция для быстрого просмотра столбца

# %%
def my_analis(data_set, column, figsize=(10, 5)):
    nan_percent = data_set[column].isna().mean() * 100
    nan_count = data_set[column].isna().sum()
    count_unique = data_set[column].nunique()
    top_values = data_set[column].value_counts(dropna=False, ascending=False).head(count_unique if count_unique <= 10 else 10)
    types = data_set[column].apply(type).value_counts()
    print(f"1) Процент пустых записей: {nan_percent}")
    print(f"2) Количество пустых записей: {nan_count}")
    print(f"3) Количество уникальных записей: {count_unique}")
    print(f"4) Топ уникальных записей для {top_values}:")
    print(f"5) Количество типов записей: {types}")
    with sns.axes_style("whitegrid"):
        plt.figure(figsize=figsize)
        sns.barplot(
            y=top_values.values, 
            x=top_values.index)


my_analis(df, "loyalty_program_type_nm", (15, 5))
# Out:
# 1) Процент пустых записей: 9.687440934614768
# 2) Количество пустых записей: 80981
# 3) Количество уникальных записей: 36
# 4) Топ уникальных записей для loyalty_program_type_nm
# Tinkoff Black                     289081
# Tinkoff Black Premium             189005
# All Airlines                      143114
# NaN                                80981
# Bravo                              41428
# All Airlines Premium Кредитный     28634
# All Airlines Premium               16277
# AllAirLinesDebit                   14824
# Tinkoff Black Private               6994
# Tinkoff Platinum                    6154
# Name: count, dtype: int64:
# 5) Количество типов записей: loyalty_program_type_nm
# <class 'str'>      754957
# <class 'float'>     80981
# Name: count, dtype: int64

# %% [markdown]
# # Удаление мало заполненных и других ненужных столбцов. А также доработка данных (bounce_cd).

# %% [markdown]
# **Процент незаполненных:**
# - children_cnt                    13.905218
# - monthly_income_amt              19.482306
# - promo_code_discount_amt         26.322287
# - order_item_cnt                  26.389637
# - avia_dep_city                   26.397053
# - avia_arr_city                   26.397053
# - bundle_nm                       29.653993
# - marital_status_cd               37.688202
# - lvn_city_nm                     43.061686
# - loyalty_accrual_rub_amt         43.135376
# - education_level_cd              43.165163
# - book_end_dttm                   79.478382
# - hotel_city                      80.590905
# - hotel_country                   80.590905
# - free_cancel_booking_dttm        90.956267
#
# **Нижнее - УДАЛЯЕМ (много пустых):**
# - last_email_send_dt              97.631643
# - bad_email_address_flg           97.631643
# - good_email_address_flg          97.631643
# - call_contact_3m_flg             99.967581
# - call_contact_1m_flg             99.967581
# - call_contact_6m_flg             99.967581
# - cancel_dttm                    100.000000
#
# **Другие столбцы для удаления (эти данные точно не буду сейчас использовать):**
# - birth_place - Место рождения
# - last_session_dttm - Дата последней сессии
# - account_rk - Идентификатор счета
# - local_book_start_dttm - Дата заезда в местном часовом поясе (для отелей)
# - time_zone_cd - Код часового пояса
# - time_zone_delta_tm - Разница часового пояса с Гринвичем

# %%
# Мало данных:
cols_to_drop = [
    "last_email_send_dt", "bad_email_address_flg", "good_email_address_flg", "call_contact_3m_flg", "call_contact_1m_flg", 
    "call_contact_6m_flg", "cancel_dttm"]

df2 = df.drop(columns=cols_to_drop)

# %%
# Эти данные точно не буду сейчас использовать
cols_to_drop = [
    "birth_place", "last_session_dttm", "account_rk", "local_book_start_dttm", "time_zone_cd", 
    "time_zone_delta_tm"]

df2 = df2.drop(columns=cols_to_drop)

# %%
my_analis(df2, "bounce_cd", (9, 4))
# Out:
# 1) Процент пустых записей: 95.25383461452883
# 2) Количество пустых записей: 796263
# 3) Количество уникальных записей: 10
# 4) Топ уникальных записей для bounce_cd
# NaN     796263
# 5,0      25261
# 15,0      7693
# 17,0      5403
# 13,0       400
# 14,0       366
# 9,0        257
# 10,0       192
# 11,0        62
# 2,0         25
# Name: count, dtype: int64:
# 5) Количество типов записей: bounce_cd
# <class 'float'>    796263
# <class 'str'>       39675
# Name: count, dtype: int64

# %% [markdown]
# bounce_cd - Код smtp-ответа от почтовой системы (отсутствие кода значит успешную отправку, все остальные smtp-коды в открытом доступе)
# Тогда заменяем NaN на 1 (доставлено), а остльные занчения на 0 (не доставлено)

# %% [markdown]
# # Просмотр общих параметров уже изменённого датасета df2

# %% [markdown]
# #### Info()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 835938 entries, 0 to 835937
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   order_online_payment_flg     786885 non-null  Int64
#  1   client_rk                    835938 non-null  object
#  2   order_rk                     835938 non-null  object
#  3   loyalty_program_type_nm      754957 non-null  object
#  4   bundle_nm                    588049 non-null  object
#  5   order_type_cd                786885 non-null  object
#  6   order_status_cd              779514 non-null  object
#  7   party_first_order_dt         786885 non-null  datetime64[ns]
#  8   party_first_order_type_dt    786767 non-null  datetime64[ns]
#  9   free_cancel_booking_dttm     75600 non-null   datetime64[ns]
#  10  created_dttm                 786885 non-null  datetime64[ns]
#  11  book_start_dttm              786885 non-null  datetime64[ns]
#  12  book_end_dttm                171548 non-null  datetime64[ns]
#  13  hotel_country                162248 non-null  object
#  14  hotel_city                   162248 non-null  object
#  15  avia_dep_city                615275 non-null  object
#  16  avia_arr_city                615275 non-null  object
#  17  promo_code_discount_amt      615900 non-null  float64
#  18  loyalty_accrual_rub_amt      475353 non-null  float64
#  19  nominal_price_eur_amt        786885 non-null  float64
#  20  nominal_price_rub_amt        786885 non-null  float64
#  21  order_item_cnt               615337 non-null  float64
#  22  month_beginning_balance_rub  776628 non-null  float64
#  23  monthly_income_amt           673078 non-null  float64
#  24  suppress_email_flg           835938 non-null  int64
#  25  suppress_call_flg            835938 non-null  int64
#  26  bounce_cd                    39675 non-null   object
#  27  last_sms_success_flg         833939 non-null  Int64
#  28  email_valid_flg              835938 non-null  int64
#  29  children_cnt                 719699 non-null  float64
#  30  age                          835937 non-null  float64
#  31  age_type_cd                  835690 non-null  object
#  32  parent_meeting_region_nm     786457 non-null  object
#  33  delivery_region_category_cd  835938 non-null  object
#  34  lvn_city_nm                  475969 non-null  object
#  35  lvn_state_nm                 783169 non-null  object
#  36  last_used_product_cd         835935 non-null  object
#  37  first_used_product_cd        833478 non-null  object
#  38  mobile_phone_operator_nm     834698 non-null  object
#  39  marital_status_cd            520888 non-null  object
#  40  education_level_cd           475104 non-null  object
#  41  gender_cd                    825781 non-null  object
#  42  last_sms_dt                  833939 non-null  datetime64[ns]
# dtypes: Int64(2), datetime64[ns](7), float64(9), int64(3), object(22)
# memory usage: 275.8+ MB

# %% [markdown]
# #### Процент незаполненных

# %%
df2["bounce_cd"] = df2["bounce_cd"].apply(lambda x: 1 if pd.isna(x) else 0)

# %%
nan_percent = df2.isna().mean() * 100
print(nan_percent)
# Out:
# order_online_payment_flg        5.868019
# client_rk                       0.000000
# order_rk                        0.000000
# loyalty_program_type_nm         9.687441
# bundle_nm                      29.653993
# order_type_cd                   5.868019
# order_status_cd                 6.749783
# party_first_order_dt            5.868019
# party_first_order_type_dt       5.882135
# free_cancel_booking_dttm       90.956267
# created_dttm                    5.868019
# book_start_dttm                 5.868019
# book_end_dttm                  79.478382
# hotel_country                  80.590905
# hotel_city                     80.590905
# avia_dep_city                  26.397053
# avia_arr_city                  26.397053
# promo_code_discount_amt        26.322287
# loyalty_accrual_rub_amt        43.135376
# nominal_price_eur_amt           5.868019
# nominal_price_rub_amt           5.868019
# order_item_cnt                 26.389637
# month_beginning_balance_rub     7.095024
# monthly_income_amt             19.482306
# suppress_email_flg              0.000000
# suppress_call_flg               0.000000
# bounce_cd                       0.000000
# last_sms_success_flg            0.239133
# email_valid_flg                 0.000000
# children_cnt                   13.905218
# age                             0.000120
# age_type_cd                     0.029667
# parent_meeting_region_nm        5.919219
# delivery_region_category_cd     0.000000
# lvn_city_nm                    43.061686
# lvn_state_nm                    6.312549
# last_used_product_cd            0.000359
# first_used_product_cd           0.294280
# mobile_phone_operator_nm        0.148336
# marital_status_cd              37.688202
# education_level_cd             43.165163
# gender_cd                       1.215042
# last_sms_dt                     0.239133
# dtype: float64

# %% [markdown]
# #### Количество уникальных значений

# %%
count_unique = df2.nunique()
print(len(count_unique))
count_unique
# Out:
# 43
# order_online_payment_flg            1
# client_rk                      148364
# order_rk                       786886
# loyalty_program_type_nm            36
# bundle_nm                           9
# order_type_cd                       2
# order_status_cd                     7
# party_first_order_dt             2500
# party_first_order_type_dt        2497
# free_cancel_booking_dttm        11325
# created_dttm                   786883
# book_start_dttm                 99276
# book_end_dttm                     558
# hotel_country                     133
# hotel_city                       3248
# avia_dep_city                     532
# avia_arr_city                     541
# promo_code_discount_amt            88
# loyalty_accrual_rub_amt          8726
# nominal_price_eur_amt            3154
# nominal_price_rub_amt           72052
# order_item_cnt                      9
# month_beginning_balance_rub    103762
# monthly_income_amt               2668
# suppress_email_flg                  2
# suppress_call_flg                   2
# bounce_cd                           2
# last_sms_success_flg                2
# email_valid_flg                     2
# children_cnt                        8
# age                                79
# age_type_cd                         4
# parent_meeting_region_nm          476
# delivery_region_category_cd         3
# lvn_city_nm                      1586
# lvn_state_nm                      304
# last_used_product_cd                4
# first_used_product_cd               9
# mobile_phone_operator_nm           60
# marital_status_cd                   6
# education_level_cd                  5
# gender_cd                           2
# last_sms_dt                       428
# dtype: int64

# %% [markdown]
# # Анализ возможных статусов заказов

# %%
my_analis(df2, "order_status_cd", (10, 4))
# Out:
# 1) Процент пустых записей: 6.74978287863454
# 2) Количество пустых записей: 56424
# 3) Количество уникальных записей: 7
# 4) Топ уникальных записей для order_status_cd
# SUC    759950
# NaN     56424
# PRC     18467
# ERR       650
# NSH       304
# CNC        84
# REJ        58
# Name: count, dtype: int64:
# 5) Количество типов записей: order_status_cd
# <class 'str'>      779514
# <class 'float'>     56424
# Name: count, dtype: int64

# %% [markdown]
# Основные три статуса это: SUC, NaN и PRC. Или "успешно", "пусто" и "в процессе" соответственно. Остальные статусы не будем исследовать из-за их незначительности.

# %% [markdown]
# # Разделение датасета по типам заказа: отель (HOT), авиабилет (AIR) и без заказа (NaN)

# %%
df2['order_type_cd'].unique()
# Out:
# array(['AIR', 'HOT', nan], dtype=object)

# %%
df2_HOT = df2[(df2['order_type_cd'] == 'HOT')] 

df2_AIR = df2[(df2['order_type_cd'] == 'AIR')] 

df2_NaN = df2[(df2['order_type_cd'].isna())]

# %% [markdown]
# ### Просмотр уникальных статусов заказа для отелей (HOT)

# %%
df2_HOT['order_status_cd'].unique()
# Out:
# array(['SUC', nan, 'REJ', 'NSH', 'CNC'], dtype=object)

# %%
df2_HOT['order_status_cd'].value_counts()
# Out:
# order_status_cd
# SUC    163794
# NSH       304
# REJ        58
# CNC        21
# Name: count, dtype: int64

# %% [markdown]
# **Статус заказа: Nan**

# %%
a = df2_HOT['order_status_cd']
a.isna()
# Out:
# 1         False
# 3          True
# 17        False
# 21        False
# 27        False
#           ...
# 835922    False
# 835923    False
# 835924    False
# 835929    False
# 835932    False
# Name: order_status_cd, Length: 171548, dtype: bool

# %%
a = df2_HOT['order_status_cd'].isna().sum()
a
# Out:
# 7371

# %%
df2_HOT[df2_HOT['order_status_cd'].isna()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7371 entries, 3 to 835875
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   order_online_payment_flg     7371 non-null   Int64
#  1   client_rk                    7371 non-null   object
#  2   order_rk                     7371 non-null   object
#  3   loyalty_program_type_nm      5625 non-null   object
#  4   bundle_nm                    5996 non-null   object
#  5   order_type_cd                7371 non-null   object
#  6   order_status_cd              0 non-null      object
#  7   party_first_order_dt         7371 non-null   datetime64[ns]
#  8   party_first_order_type_dt    7312 non-null   datetime64[ns]
#  9   free_cancel_booking_dttm     3375 non-null   datetime64[ns]
#  10  created_dttm                 7371 non-null   datetime64[ns]
#  11  book_start_dttm              7371 non-null   datetime64[ns]
#  12  book_end_dttm                7371 non-null   datetime64[ns]
#  13  hotel_country                0 non-null      object
#  14  hotel_city                   0 non-null      object
#  15  avia_dep_city                0 non-null      object
#  16  avia_arr_city                0 non-null      object
#  17  promo_code_discount_amt      0 non-null      float64
#  18  loyalty_accrual_rub_amt      0 non-null      float64
#  19  nominal_price_eur_amt        7371 non-null   float64
#  20  nominal_price_rub_amt        7371 non-null   float64
#  21  order_item_cnt               0 non-null      float64
#  22  month_beginning_balance_rub  7308 non-null   float64
#  23  monthly_income_amt           6046 non-null   float64
#  24  suppress_email_flg           7371 non-null   int64
#  25  suppress_call_flg            7371 non-null   int64
#  26  bounce_cd                    7371 non-null   int64
#  27  last_sms_success_flg         7351 non-null   Int64
#  28  email_valid_flg              7371 non-null   int64
#  29  children_cnt                 6806 non-null   float64
#  30  age                          7371 non-null   float64
#  31  age_type_cd                  7367 non-null   object
#  32  parent_meeting_region_nm     6967 non-null   object
#  33  delivery_region_category_cd  7371 non-null   object
#  34  lvn_city_nm                  4046 non-null   object
#  35  lvn_state_nm                 6918 non-null   object
#  36  last_used_product_cd         7371 non-null   object
#  37  first_used_product_cd        7355 non-null   object
#  38  mobile_phone_operator_nm     7370 non-null   object
#  39  marital_status_cd            4768 non-null   object
#  40  education_level_cd           4412 non-null   object
#  41  gender_cd                    7347 non-null   object
#  42  last_sms_dt                  7351 non-null   datetime64[ns]
# dtypes: Int64(2), datetime64[ns](7), float64(9), int64(4), object(21)
# memory usage: 2.5+ MB

# %% [markdown]
# **Судя по всему это какие-то неудачные заказы. В них также не указаны отель (страна + город), а также даже количсетво позиций в заказе => УДАЛЯЕМ**

# %%
df2_HOT = df2_HOT.dropna(subset=['order_status_cd'])

# %% [markdown]
# **Также удаляем строки с другими мало встречающимимся статусами в 'order_status_cd': NSH, REJ, CNC**

# %%
df2_HOT = df2_HOT[~df2_HOT['order_status_cd'].isin(['NSH', 'REJ', 'CNC'])]

# %% [markdown]
# **Проверка значений**

# %%
a = df2_HOT['order_status_cd'].unique()
a
# Out:
# array(['SUC'], dtype=object)

# %%
a = df2_HOT['order_status_cd'].value_counts()

# %%
a = df2_HOT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 163794 entries, 1 to 835932
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   order_online_payment_flg     163794 non-null  Int64
#  1   client_rk                    163794 non-null  object
#  2   order_rk                     163794 non-null  object
#  3   loyalty_program_type_nm      162883 non-null  object
#  4   bundle_nm                    132500 non-null  object
#  5   order_type_cd                163794 non-null  object
#  6   order_status_cd              163794 non-null  object
#  7   party_first_order_dt         163794 non-null  datetime64[ns]
#  8   party_first_order_type_dt    163794 non-null  datetime64[ns]
#  9   free_cancel_booking_dttm     72087 non-null   datetime64[ns]
#  10  created_dttm                 163794 non-null  datetime64[ns]
#  11  book_start_dttm              163794 non-null  datetime64[ns]
#  12  book_end_dttm                163794 non-null  datetime64[ns]
#  13  hotel_country                161868 non-null  object
#  14  hotel_city                   161868 non-null  object
#  15  avia_dep_city                0 non-null       object
#  16  avia_arr_city                0 non-null       object
#  17  promo_code_discount_amt      561 non-null     float64
#  18  loyalty_accrual_rub_amt      104914 non-null  float64
#  19  nominal_price_eur_amt        163794 non-null  float64
#  20  nominal_price_rub_amt        163794 non-null  float64
#  21  order_item_cnt               0 non-null       float64
#  22  month_beginning_balance_rub  162375 non-null  float64
#  23  monthly_income_amt           133651 non-null  float64
#  24  suppress_email_flg           163794 non-null  int64
#  25  suppress_call_flg            163794 non-null  int64
#  26  bounce_cd                    163794 non-null  int64
#  27  last_sms_success_flg         163643 non-null  Int64
#  28  email_valid_flg              163794 non-null  int64
#  29  children_cnt                 148792 non-null  float64
#  30  age                          163794 non-null  float64
#  31  age_type_cd                  163716 non-null  object
#  32  parent_meeting_region_nm     153612 non-null  object
#  33  delivery_region_category_cd  163794 non-null  object
#  34  lvn_city_nm                  91157 non-null   object
#  35  lvn_state_nm                 152615 non-null  object
#  36  last_used_product_cd         163794 non-null  object
#  37  first_used_product_cd        163349 non-null  object
#  38  mobile_phone_operator_nm     163732 non-null  object
#  39  marital_status_cd            103491 non-null  object
#  40  education_level_cd           95933 non-null   object
#  41  gender_cd                    163128 non-null  object
#  42  last_sms_dt                  163643 non-null  datetime64[ns]
# dtypes: Int64(2), datetime64[ns](7), float64(9), int64(4), object(21)
# memory usage: 55.3+ MB

# %% [markdown]
# ### Просмотр уникальных статусов заказа для авиабилетов (AIR)

# %%
df2_AIR['order_status_cd'].unique()
# Out:
# array(['SUC', 'PRC', 'ERR', 'CNC', 'BRN'], dtype=object)

# %%
df2_AIR['order_status_cd'].value_counts()
# Out:
# order_status_cd
# SUC    596156
# PRC     18467
# ERR       650
# CNC        63
# BRN         1
# Name: count, dtype: int64

# %%
df2_AIR['order_status_cd'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Оставляем два самых часто встречающихся статуса: SUC и PRC, то есть "успешно" и "в процессе" соответственно. Остальные - УДАЛЯЕМ. Пустных значений (NaN) - нет**

# %%
df2_AIR = df2_AIR[~df2_AIR['order_status_cd'].isin(['ERR', 'CNC', 'BRN'])]

# %% [markdown]
# **Проверка значений**

# %%
df2_AIR['order_status_cd'].unique()
# Out:
# array(['SUC', 'PRC'], dtype=object)

# %%
df2_AIR['order_status_cd'].value_counts()
# Out:
# order_status_cd
# SUC    596156
# PRC     18467
# Name: count, dtype: int64

# %% [markdown]
# ### Просмотр заказов с невыбранным типом отель (HOT) или авиабилет (AIR),  то есть 'order_type_cd' == NaN

# %%
df2_NaN['order_status_cd'].unique()
# Out:
# array([nan], dtype=object)

# %%
df2_NaN.shape
# Out:
# (49053, 43)

# %%
df2_NaN['client_rk'].nunique()
# Out:
# 49053

# %%
df2['order_rk'].value_counts(dropna=False, ascending=False).head(10)
# Out:
# order_rk
# 9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6c9bc9d493a23be9de0    49053
# fe1c6ce13774d102c655df4c01d54c34d495ef3d4c7e638d5746c1c7adbcc5a0        1
# f8ff89531ccbbe2c6a19c68458f73de48dfabdfe3ce10907a7f047658cc0c0df        1
# f3b815b9a14cef1fc4ce25ee3543ee5ac18c158fc6edeb98c734b51d755f7226        1
# 455ba382f9cbc5c691e4d82e0b88694916b112d4d6f46069424637e2364134e3        1
# cb60bd2a051f7530c7d6d91184550bf90a0204aaa3e517e7ccf072765bba7fa9        1
# dd96b552ae8d655a1e17789f528a1d9673002214f6e3548cfd2dbb1eaa582dfa        1
# 230e8295629101504cdcf43c33689b18ff08954ed2d5a6b74400f77231316d45        1
# 707a9fc7f3d1b7561c4104d5a15b6617969afb3cdc60d4a875791f6ff6acbcf4        1
# 38886291241859cf3005da351b7d7201be789f9e59c81f2d1154ce086161dd72        1
# Name: count, dtype: int64

# %%
df2_NaN['order_rk'].value_counts()
# Out:
# order_rk
# 9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6c9bc9d493a23be9de0    49053
# Name: count, dtype: int64

# %%
df2_NaN['client_rk'].nunique()
# Out:
# 49053

# %%
df2_NaN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49053 entries, 59 to 835908
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   order_online_payment_flg     0 non-null      Int64
#  1   client_rk                    49053 non-null  object
#  2   order_rk                     49053 non-null  object
#  3   loyalty_program_type_nm      0 non-null      object
#  4   bundle_nm                    0 non-null      object
#  5   order_type_cd                0 non-null      object
#  6   order_status_cd              0 non-null      object
#  7   party_first_order_dt         0 non-null      datetime64[ns]
#  8   party_first_order_type_dt    0 non-null      datetime64[ns]
#  9   free_cancel_booking_dttm     0 non-null      datetime64[ns]
#  10  created_dttm                 0 non-null      datetime64[ns]
#  11  book_start_dttm              0 non-null      datetime64[ns]
#  12  book_end_dttm                0 non-null      datetime64[ns]
#  13  hotel_country                0 non-null      object
#  14  hotel_city                   0 non-null      object
#  15  avia_dep_city                0 non-null      object
#  16  avia_arr_city                0 non-null      object
#  17  promo_code_discount_amt      0 non-null      float64
#  18  loyalty_accrual_rub_amt      0 non-null      float64
#  19  nominal_price_eur_amt        0 non-null      float64
#  20  nominal_price_rub_amt        0 non-null      float64
#  21  order_item_cnt               0 non-null      float64
#  22  month_beginning_balance_rub  0 non-null      float64
#  23  monthly_income_amt           37000 non-null  float64
#  24  suppress_email_flg           49053 non-null  int64
#  25  suppress_call_flg            49053 non-null  int64
#  26  bounce_cd                    49053 non-null  int64
#  27  last_sms_success_flg         48750 non-null  Int64
#  28  email_valid_flg              49053 non-null  int64
#  29  children_cnt                 38129 non-null  float64
#  30  age                          49052 non-null  float64
#  31  age_type_cd                  49012 non-null  object
#  32  parent_meeting_region_nm     44736 non-null  object
#  33  delivery_region_category_cd  49053 non-null  object
#  34  lvn_city_nm                  28029 non-null  object
#  35  lvn_state_nm                 42273 non-null  object
#  36  last_used_product_cd         49050 non-null  object
#  37  first_used_product_cd        48822 non-null  object
#  38  mobile_phone_operator_nm     48914 non-null  object
#  39  marital_status_cd            27988 non-null  object
#  40  education_level_cd           24251 non-null  object
#  41  gender_cd                    48677 non-null  object
#  42  last_sms_dt                  48750 non-null  datetime64[ns]
# dtypes: Int64(2), datetime64[ns](7), float64(9), int64(4), object(21)
# memory usage: 16.6+ MB

# %% [markdown]
# **Таким образом, каждой записи из df2_NaN (не HOT и не AIR) соответствует ровно один id клиента без повторов. Также у каждой такой записи один и тот же id заказа. Поэтому будем считать, что все записи в df2_NaN соответствуют клиентам не совершившим ни одного заказа.**

# %% [markdown]
# **Количество уникальных клиентов, не совершивших ни одной успешной покупки:**

# %%
count_NaN_clients = df2_NaN['client_rk'].nunique()

# %%
print(f"Количество уникальных клиентов, не совершивших ни одной успешной покупки: {count_NaN_clients}")
# Out:
# Количество уникальных клиентов, не совершивших ни одной успешной покупки: 49053

# %% [markdown]
# # Соотношение успешных (SUC) заказов авиабилетов (AIR) и бронирования отеля (HOT)

# %%
suc_hot_count = df2_HOT[df2_HOT['order_status_cd'] == 'SUC'].shape[0]
suc_air_count = df2_AIR[df2_AIR['order_status_cd'] == 'SUC'].shape[0]

labels = [f'HOT\n{suc_hot_count}', f'AIR\n{suc_air_count}']
sizes = [suc_hot_count, suc_air_count]
colors = ['green', 'orange']

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title(f'Соотношение успешных заказов: отель (HOT) и авиабилет (AIR)\nпри общей выборке {suc_hot_count + suc_air_count} заказов', fontsize=14)

plt.legend(labels, title="Типы заказов", loc="best", fontsize=12)
plt.show()

# %% [markdown]
# **Количество бронирований отелей:**

# %%
suc_hot_count
# Out:
# 163794

# %% [markdown]
# **Количество заказов авиабилетов:**

# %%
suc_air_count
# Out:
# 596156

# %% [markdown]
# # Соотношение уникальных клиентов, которые либо только успешно заказывали авиабилеты (AIR Client), либо только успешно бронированли отель (HOT Client), либо успешно совершали обе покупки (HOT + AIR Client). Совместные покупки (HOT + AIR) не обязательно относятся к одной поездке

# %% [markdown]
# **Количество уникальных клиентов, когда-либо совершивших успешную покупку:**

# %%
clients_suc = df2[df2['order_status_cd'] == 'SUC'].groupby('client_rk')
count_suc_clients = clients_suc.ngroups

# %%
print(f'Количество уникальных клиентов, когда-либо совершивших успешную покупку: {count_suc_clients}')
# Out:
# Количество уникальных клиентов, когда-либо совершивших успешную покупку: 99232

# %%
clients_suc_order_type = clients_suc['order_type_cd'].unique().apply(lambda x:  'HOT + AIR' if len(x) == 2 else x[0])
clients_suc_order_type
# Out:
# client_rk
# 000047e2e70a562001b2b9230bc95c7efcb1103b32717107ada2e90cce3d22b0          AIR
# 00019ea581c09c72f249b6714222e8931e30448f7ed2eb3358165b41415e708d          AIR
# 0001d4e275c931cb346856169aa616a8dd14c04de1d21dd82a3f46c2fa146bc2          AIR
# 00023bb2f46b332c4a84cf3391a6be24b05cedad6f48979f1dd0f65f7b90b406          HOT
# 00025fad046ff0ce2c86eb2fe19641c56f13034e9224203a18796004547a8b73          HOT
#                                                                       ...
# fffd7372b65bbb5aad8538f0e4d11288543caf7598f73745902cbe45cf39d889          AIR
# fffdc43175ca31b6890bddfbc948d95f959f6b62b43fa2e08ad15a865b16a6aa          AIR
# fffdd44ec229e89655575bf56a9aabb56ea013872c5bb0e5f73f9ce4e95e775a          AIR
# fffe80964b7e587ee2c26601a9a80261d1583db7c514fcbffdab40a668a7804d    HOT + AIR
# ffff72b45a2425899261e12f738a12cd31fa70e28548e965769f9cb53fbdfcfe          AIR
# Name: order_type_cd, Length: 99232, dtype: object

# %%
clients_suc_order_type.unique()
# Out:
# array(['AIR', 'HOT', 'HOT + AIR'], dtype=object)

# %%
clients_suc_order_type = clients_suc_order_type.value_counts()

# %%
clients_suc_order_type
# Out:
# order_type_cd
# AIR          52539
# HOT + AIR    34141
# HOT          12552
# Name: count, dtype: int64

# %%
labels = ['HOT', 'AIR', 'HOT + AIR']
sizes = [clients_suc_order_type[labels[0]], clients_suc_order_type[labels[1]], clients_suc_order_type[labels[2]]]
colors = ['green', 'orange', 'red']

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Соотношение уникальных клиентов совершивших покупки типа: отель (HOT), авиабилет (AIR) и отель + авиабилет (HOT + AIR)', fontsize=14)

plt.legend(labels, title="Типы заказов", loc="best", fontsize=12)
plt.show()

# %% [markdown]
# **Таким образом, большинство клиентов покупает что-то одно: либо авиабилеты (преимущественно), либо бронирует отел. И только 34% людей когда либо покупали и номер в отеле и авиабилеты. Причём сервисом пользуются в основном для заказов авиабилетов**

# %% [markdown]
# # Уникальные клиенты 4 типов: совершившие одну из покупок (отель (HOT), авиабилет (AIR) и отель + авиабилет (HOT + AIR)), а также не совершившие ни одной покупки

# %%
labels = ['HOT', 'AIR', 'HOT + AIR', 'Без покупок']
sizes = [clients_suc_order_type[labels[0]], clients_suc_order_type[labels[1]], clients_suc_order_type[labels[2]], count_NaN_clients]
colors = ['green', 'orange', 'red', 'grey']

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Уникальные клиенты, совершившие одну из покупок (отель (HOT), авиабилет (AIR) и отель + авиабилет (HOT + AIR)), \
а также вообще без покупок', fontsize=14)

plt.legend(labels, title="Типы заказов", loc="best", fontsize=12)
plt.show()

# %% [markdown]
# **Итого, около 33% клиентов не совершила ни одной покупки => нужно проверить в чём их отличие**

# %% [markdown]
# # Временная зависимость бронирования отелей по дням

# %%
start_date = pd.to_datetime('2024-01-01')
end_date = pd.to_datetime('2024-12-30')

df2_HOT_interval = df2_HOT[(df2_HOT['created_dttm'] >= start_date) & (df2_HOT['created_dttm'] <= end_date)].copy()

df2_HOT_interval['date'] = df2_HOT_interval['created_dttm'].dt.date

counts_of_bookings_hot = df2_HOT_interval.groupby(['date', 'order_status_cd']).size().reset_index(name='count')
counts_of_bookings_hot
# Out:
#            date order_status_cd  count
# 0    2024-01-01             SUC    222
# 1    2024-01-02             SUC    273
# 2    2024-01-03             SUC    279
# 3    2024-01-04             SUC    249
# 4    2024-01-05             SUC    278
# ..          ...             ...    ...
# 307  2024-11-03             SUC    433
# 308  2024-11-04             SUC    387
# 309  2024-11-05             SUC    510
# 310  2024-11-06             SUC    488
# 311  2024-11-07             SUC      5
#
# [312 rows x 3 columns]

# %%
import matplotlib.dates as mdates

subset = counts_of_bookings_hot[counts_of_bookings_hot['order_status_cd'] == 'SUC']

plt.figure(figsize=(14, 6))
plt.plot(subset['date'], subset['count'], label='SUC', linewidth=1.8, color='green')

plt.title('Количество (SUC) бронирований отелей (HOT) по датам')
plt.xlabel('Дата')
plt.ylabel('Количество заказов')

plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

plt.gca().xaxis.set_minor_locator(mdates.WeekdayLocator(interval=1, byweekday=0))

plt.grid(True, which='major', linewidth=1.2, alpha=0.8, color='black', axis='x')
plt.grid(True, which='minor', linewidth=0.5, alpha=0.2, axis='x')

plt.xticks(rotation=45, ha='right')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Явно наблюдаются резкие большие пики успешных бронирований впоть до нескольких тысяч, а также регулярные более мелкие скачки, которые предположительно возникают каждую неделю.**

# %% [markdown]
# # Временная зависимость бронирования отелей по месяцам (исключая ноябрь и декабрь, т.к. неполные)

# %%
start_date = pd.to_datetime('2024-01-01')
end_date = pd.to_datetime('2024-10-30')

df2_HOT_interval = df2_HOT[(df2_HOT['created_dttm'] >= start_date) & (df2_HOT['created_dttm'] <= end_date)].copy()

df2_HOT_interval['month'] = df2_HOT_interval['created_dttm'].dt.month
counts_by_month = df2_HOT_interval.groupby(['month', 'order_status_cd']).size().reset_index(name='count')
counts_by_month
# Out:
#    month order_status_cd  count
# 0      1             SUC  11139
# 1      2             SUC  12282
# 2      3             SUC  16018
# 3      4             SUC  16928
# 4      5             SUC  17065
# 5      6             SUC  17363
# 6      7             SUC  17724
# 7      8             SUC  17780
# 8      9             SUC  18192
# 9     10             SUC  15555

# %%
import matplotlib.dates as mdates


subset = counts_by_month[counts_by_month['order_status_cd'] == 'SUC']

plt.figure(figsize=(14, 6))
plt.plot(subset['month'], subset['count'], marker='o', linewidth=1.8, color='green', label='SUC')

plt.title('Количество (SUC) бронирований отелей (HOT) по месяцам за 2024 год')
plt.xlabel('Месяц')
plt.ylabel('Количество заказов')

plt.xticks(range(1, 13))  
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Временная зависимость бронирования авиабилетов по дням

# %%
start_date = pd.to_datetime('2024-01-01')
end_date = pd.to_datetime('2024-12-30')

df2_AIR_interval = df2_AIR[(df2_AIR['created_dttm'] >= start_date) & (df2_AIR['created_dttm'] <= end_date)].copy()
df2_AIR_interval['date'] = df2_AIR_interval['created_dttm'].dt.date

counts_of_bookings_air = df2_AIR_interval.groupby(['date', 'order_status_cd']).size().reset_index(name='count')
counts_of_bookings_air
# Out:
#            date order_status_cd  count
# 0    2024-01-01             PRC     47
# 1    2024-01-01             SUC   1111
# 2    2024-01-02             PRC     45
# 3    2024-01-02             SUC   1409
# 4    2024-01-03             PRC     58
# ..          ...             ...    ...
# 617  2024-11-04             SUC   1520
# 618  2024-11-05             PRC     41
# 619  2024-11-05             SUC   2098
# 620  2024-11-06             PRC     14
# 621  2024-11-06             SUC   1522
#
# [622 rows x 3 columns]

# %%
import matplotlib.dates as mdates

subset = counts_of_bookings_air[counts_of_bookings_air['order_status_cd'] == 'SUC']

plt.figure(figsize=(14, 6))
plt.plot(subset['date'], subset['count'], label='SUC', linewidth=1.8, color='orange')

plt.title('Количество (SUC) бронирований авиабилетов (AIR) по датам')
plt.xlabel('Дата')
plt.ylabel('Количество заказов')

plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

plt.gca().xaxis.set_minor_locator(mdates.WeekdayLocator(interval=1))

plt.grid(True, which='major', linewidth=1.2, alpha=0.8, color='black', axis='x')
plt.grid(True, which='minor', linewidth=0.5, alpha=0.2, color='black', axis='x')

plt.xticks(rotation=45, ha='right')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Временная зависимость бронирования авиабилетов по месяцам (исключая ноябрь и декабрь, т.к. неполные)

# %%
start_date = pd.to_datetime('2024-01-01')
end_date = pd.to_datetime('2024-10-31')

df2_AIR_interval = df2_AIR[(df2_AIR['created_dttm'] >= start_date) & (df2_AIR['created_dttm'] <= end_date)].copy()
df2_AIR_interval['month'] = df2_AIR_interval['created_dttm'].dt.month

counts_by_month_air = df2_AIR_interval.groupby(['month', 'order_status_cd']).size().reset_index(name='count')
counts_by_month_air
# Out:
#     month order_status_cd  count
# 0       1             PRC   1891
# 1       1             SUC  52340
# 2       2             PRC   1672
# 3       2             SUC  51258
# 4       3             PRC   1987
# 5       3             SUC  53856
# 6       4             PRC   1910
# 7       4             SUC  55966
# 8       5             PRC   1834
# 9       5             SUC  58008
# 10      6             PRC   1916
# 11      6             SUC  63115
# 12      7             PRC   2014
# 13      7             SUC  66137
# 14      8             PRC   1918
# 15      8             SUC  64335
# 16      9             PRC   1804
# 17      9             SUC  61324
# 18     10             PRC   1335
# 19     10             SUC  58247

# %%
subset = counts_by_month_air[counts_by_month_air['order_status_cd'] == 'SUC']

plt.figure(figsize=(14, 6))
plt.plot(subset['month'], subset['count'], marker='o', linewidth=1.8, color='orange', label='SUC')

plt.title('Количество успешных (SUC) бронирований авиабилетов (AIR) по месяцам за 2024 год')
plt.xlabel('Месяц')
plt.ylabel('Количество заказов')

plt.xticks(range(1, 13))
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Заметно явное снижение спроса в зимний период. Предположительно из-за того, что люди предпочитают отдыхать дома => имеет смысл уменьшить затраты на привлечение поскольку эффективность этого будет меньше из-за меньшего спроса**
#
# - **Соответственно предлагать различные карты и подписки имеет смысл не в зимние месяцы, поскольку клиент не будет ощущать явной целеесообразности этого из-за нежеленая сейчас куда-либо ехать, а ближе к сезону отпусков. Причём для отелей и авиабилетов эти моменты разные, что также явно видно по графикам: количество бронирований отелей резко возрасает уже в период с февраля по март, а для авиабилетов этот момент наступает позже. То есть отели бронируют сильно заранее, тогда как билеты на самолёт уже ближе к вылету**

# %% [markdown]
# ### Количество заказов авиабилетов со статусом "в процессе" по месяцам:
# (просто чтобы показать, что они сохраняются на протяжении всего времени)

# %%
subset = counts_by_month_air[counts_by_month_air['order_status_cd'] == 'PRC']

plt.figure(figsize=(14, 6))
plt.plot(subset['month'], subset['count'], marker='o', linewidth=1.8, color='orange', label='PRC')

plt.title('Количество незавершённых (PRC) бронирований авиабилетов (AIR) по месяцам за 2024 год')
plt.xlabel('Месяц')
plt.ylabel('Количество заказов')

plt.xticks(range(1, 13))
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Бронирование авиабилетов и отелей на одном графике

# %%
start_date = pd.to_datetime('2024-01-01')
end_date = pd.to_datetime('2024-12-01')

df2_AIR_interval = df2_AIR[(df2_AIR['created_dttm'] >= start_date) & (df2_AIR['created_dttm'] <= end_date)].copy()
df2_AIR_interval['date'] = df2_AIR_interval['created_dttm'].dt.date

df2_HOT_interval = df2_HOT[(df2_HOT['created_dttm'] >= start_date) & (df2_HOT['created_dttm'] <= end_date)].copy()
df2_HOT_interval['date'] = df2_HOT_interval['created_dttm'].dt.date

counts_of_bookings_air = df2_AIR_interval.groupby(['date', 'order_status_cd']).size().reset_index(name='count')
counts_of_bookings_hot = df2_HOT_interval.groupby(['date', 'order_status_cd']).size().reset_index(name='count')
counts_of_bookings_air
# Out:
#            date order_status_cd  count
# 0    2024-01-01             PRC     47
# 1    2024-01-01             SUC   1111
# 2    2024-01-02             PRC     45
# 3    2024-01-02             SUC   1409
# 4    2024-01-03             PRC     58
# ..          ...             ...    ...
# 617  2024-11-04             SUC   1520
# 618  2024-11-05             PRC     41
# 619  2024-11-05             SUC   2098
# 620  2024-11-06             PRC     14
# 621  2024-11-06             SUC   1522
#
# [622 rows x 3 columns]

# %%
counts_of_bookings_hot
# Out:
#            date order_status_cd  count
# 0    2024-01-01             SUC    222
# 1    2024-01-02             SUC    273
# 2    2024-01-03             SUC    279
# 3    2024-01-04             SUC    249
# 4    2024-01-05             SUC    278
# ..          ...             ...    ...
# 307  2024-11-03             SUC    433
# 308  2024-11-04             SUC    387
# 309  2024-11-05             SUC    510
# 310  2024-11-06             SUC    488
# 311  2024-11-07             SUC      5
#
# [312 rows x 3 columns]

# %%
import matplotlib.dates as mdates


plt.figure(figsize=(25, 10))

subset = counts_of_bookings_hot[counts_of_bookings_hot['order_status_cd'] == 'SUC']
plt.plot(subset['date'], subset['count'], label='HOT', linewidth=1.8, color='green')

subset = counts_of_bookings_air[counts_of_bookings_air['order_status_cd'] == 'SUC']
plt.plot(subset['date'], subset['count'], label='AIR', linewidth=1.8, color='orange')

plt.title('Количество (SUC) бронирований отелей и авиабилетов (HOT + AIR) по датам', fontsize=20)
plt.xlabel('Дата', fontsize=15)
plt.ylabel('Количество заказов', fontsize=15)

plt.gca().xaxis.set_major_locator(mdates.WeekdayLocator(interval=1, byweekday=0))
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d'))

plt.gca().xaxis.set_minor_locator(mdates.DayLocator(interval=1))  

plt.grid(True, which='major', linewidth=1.2, alpha=0.8, color='black', axis='x')
# plt.grid(False, which='major', axis='x')
plt.grid(True, which='major', linewidth=0.5, alpha=1, color='grey', axis='y')
plt.grid(True, which='minor', linewidth=0.5, alpha=1)

plt.xticks(rotation=45, ha='right', fontsize=15)
plt.legend(fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Наблюдаются часто встречающиеся малые скачки и большие пики заказов, особенно выраженные для отелей. Причём какой-либо явной зависимости между большими пиками для отелей и количеством покупок авиабилетов не наблюдается, что объясняется малой частью пользователей, покупающих обе услуги.**

# %% [markdown]
# # Вырезаем данные с явными большими пиками.

# %% [markdown]
# **Добавляем столбцы "даты" (без времени) и "дня недели" для удобства дальнейшего использования и создания статистики по дням недели**

# %%
df2_HOT['date'] = df2_HOT['created_dttm'].dt.date
df2_HOT['weekday'] = pd.to_datetime(df2_HOT['date']).dt.day_name()
df2_HOT['month'] = df2_HOT['created_dttm'].dt.month

# %%
df2_AIR['date'] = df2_AIR['created_dttm'].dt.date
df2_AIR['weekday'] = pd.to_datetime(df2_AIR['date']).dt.day_name()
df2_AIR['month'] = df2_AIR['created_dttm'].dt.month

# %% [markdown]
# **Вырезаем не отдельные дни, а целые недели, содержащие соответствующий пик, чтобы потом собрать более достоверную статистику по неделям**

# %%
intervals = [
    ('2024-01-15', '2024-01-21'),
    ('2024-03-04', '2024-03-17'),  
    ('2024-04-01', '2024-04-07'),
    ('2024-05-13', '2024-05-19'),
    ('2024-06-17', '2024-06-30'), 
    ('2024-07-22', '2024-07-28'),
    ('2024-08-12', '2024-08-18'),
    ('2024-09-09', '2024-09-15'),
    ('2024-09-23', '2024-09-29'),
]

# %%
pd.to_datetime('2024-03-04').day_name()
# Out:
# 'Monday'

# %%
df2_HOT_interval = df2_HOT.copy()
for s, e in intervals:
    s_d = pd.to_datetime(s).date()
    e_d = pd.to_datetime(e).date()
    df2_HOT_interval = df2_HOT_interval[~((df2_HOT_interval['date'] >= s_d) & (df2_HOT_interval['date'] <= e_d))]

df2_AIR_interval = df2_AIR.copy()
for s, e in intervals:
    s_d = pd.to_datetime(s).date()
    e_d = pd.to_datetime(e).date()
    df2_AIR_interval = df2_AIR_interval[~((df2_AIR_interval['date'] >= s_d) & (df2_AIR_interval['date'] <= e_d))]

# %%
counts_of_bookings_air = df2_AIR_interval.groupby(['date', 'order_status_cd']).size().reset_index(name='count')
counts_of_bookings_hot = df2_HOT_interval.groupby(['date', 'order_status_cd']).size().reset_index(name='count')
counts_of_bookings_hot
# Out:
#            date order_status_cd  count
# 0    2024-01-01             SUC    222
# 1    2024-01-02             SUC    273
# 2    2024-01-03             SUC    279
# 3    2024-01-04             SUC    249
# 4    2024-01-05             SUC    278
# ..          ...             ...    ...
# 230  2024-11-03             SUC    433
# 231  2024-11-04             SUC    387
# 232  2024-11-05             SUC    510
# 233  2024-11-06             SUC    488
# 234  2024-11-07             SUC      5
#
# [235 rows x 3 columns]

# %%
counts_of_bookings_air
# Out:
#            date order_status_cd  count
# 0    2024-01-01             PRC     47
# 1    2024-01-01             SUC   1111
# 2    2024-01-02             PRC     45
# 3    2024-01-02             SUC   1409
# 4    2024-01-03             PRC     58
# ..          ...             ...    ...
# 463  2024-11-04             SUC   1520
# 464  2024-11-05             PRC     41
# 465  2024-11-05             SUC   2098
# 466  2024-11-06             PRC     14
# 467  2024-11-06             SUC   1522
#
# [468 rows x 3 columns]

# %%
import matplotlib.dates as mdates


plt.figure(figsize=(25, 10))

subset = counts_of_bookings_hot[counts_of_bookings_hot['order_status_cd'] == 'SUC']
plt.plot(subset['date'], subset['count'], label='HOT', linewidth=1.8, color='green')

subset = counts_of_bookings_air[counts_of_bookings_air['order_status_cd'] == 'SUC']
plt.plot(subset['date'], subset['count'], label='AIR', linewidth=1.8, color='orange')

plt.title('Количество (SUC) бронирований отелей и авиабилетов (HOT + AIR) по датам', fontsize=20)
plt.xlabel('Дата', fontsize=15)
plt.ylabel('Количество заказов', fontsize=15)

plt.gca().xaxis.set_major_locator(mdates.WeekdayLocator(interval=1, byweekday=0))
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m-%d'))

plt.gca().xaxis.set_minor_locator(mdates.DayLocator(interval=1))  

plt.grid(True, which='major', linewidth=1.2, alpha=0.8, color='black', axis='x')
# plt.grid(False, which='major', axis='x')
plt.grid(True, which='major', linewidth=0.5, alpha=1, color='grey', axis='y')
plt.grid(True, which='minor', linewidth=0.5, alpha=1)

plt.xticks(rotation=45, ha='right', fontsize=15)
plt.legend(fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Статистика заказов по дням недели (без учёта пиковых значений в отдельные дни)

# %%
counts_of_bookings_day_air = df2_AIR_interval.groupby(['weekday', 'order_status_cd']).size().reset_index(name='count')
counts_of_bookings_day_hot = df2_HOT_interval.groupby(['weekday', 'order_status_cd']).size().reset_index(name='count')

# %%
week_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']


subset_hot = counts_of_bookings_day_hot[counts_of_bookings_day_hot['order_status_cd'] == 'SUC'].copy()
subset_hot['weekday'] = pd.Categorical(subset_hot['weekday'], categories=week_order, ordered=True)
subset_hot = subset_hot.sort_values('weekday')

plt.figure(figsize=(8, 5))
plt.bar(subset_hot['weekday'], subset_hot['count'], color='green')
plt.title('Количество SUC заказов (HOT) по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество заказов')
plt.show()


subset_air = counts_of_bookings_day_air[counts_of_bookings_day_air['order_status_cd'] == 'SUC'].copy()
subset_air['weekday'] = pd.Categorical(subset_air['weekday'], categories=week_order, ordered=True)
subset_air = subset_air.sort_values('weekday')

plt.figure(figsize=(8, 5))
plt.bar(subset_air['weekday'], subset_air['count'], color='orange')
plt.title('Количество SUC заказов (AIR) по дням недели')
plt.xlabel('День недели')
plt.ylabel('Количество заказов')
plt.show()

# %%
subset_hot['percent'] = subset_hot['count'] / subset_hot['count'].max() * 100

plt.figure(figsize=(8, 5))
plt.plot(subset_hot['weekday'], subset_hot['percent'], color='green', marker='o')
plt.fill_between(subset_hot['weekday'], subset_hot['percent'], color='green', alpha=0.3)
plt.grid(True, alpha=0.3)
plt.title('Доля SUC заказов (HOT) по дням недели, % от максимума')
plt.xlabel('День недели')
plt.ylabel('Процент от максимального значения')
plt.minorticks_on()
plt.grid(True, which='major', linewidth=1, alpha=0.5)
plt.grid(True, which='minor', linewidth=0.5, alpha=0.3)
plt.show()


subset_air['percent'] = subset_air['count'] / subset_air['count'].max() * 100

plt.figure(figsize=(8, 5))
plt.plot(subset_air['weekday'], subset_air['percent'], color='orange', marker='o')
plt.fill_between(subset_air['weekday'], subset_air['percent'], color='orange', alpha=0.3)
plt.grid(True, alpha=0.3)
plt.title('Доля SUC заказов (AIR) по дням недели, % от максимума')
plt.xlabel('День недели')
plt.ylabel('Процент от максимального значения')
plt.minorticks_on()
plt.grid(True, which='major', linewidth=1, alpha=0.5)
plt.grid(True, which='minor', linewidth=0.5, alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(10, 6))

subset_hot['percent'] = subset_hot['count'] / subset_hot['count'].max() * 100
plt.plot(subset_hot['weekday'], subset_hot['percent'], color='green', linewidth=2, marker='o', label='HOT')
plt.fill_between(subset_hot['weekday'], subset_hot['percent'], color='green', alpha=0.2)

subset_air['percent'] = subset_air['count'] / subset_air['count'].max() * 100
plt.plot(subset_air['weekday'], subset_air['percent'], color='orange', linewidth=2, marker='o', label='AIR')
plt.fill_between(subset_air['weekday'], subset_air['percent'], color='orange', alpha=0.2)

plt.ylim(60, 105)
plt.xlabel('День недели', fontsize=12)
plt.ylabel('Процент от максимального значения', fontsize=12)
plt.title('Доля SUC заказов по дням недели', fontsize=14)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.legend()
plt.minorticks_on()
plt.grid(True, which='major', linewidth=1, alpha=0.5)
plt.grid(True, which='minor', linewidth=0.5, alpha=0.3)
plt.show()

# %% [markdown]
# - **Малые скачки на графиках бронирований имеют еженедельных характер, что также подтвеждается из этих графиков. Таким образом можно предположить, что спрос выше в первой половине недели, в особенности для авиабилетов (ведь их покупают непосредственно перед отъездом). Следовательно, осуществлять привлечение следует именно в первой половине недели и в особенности для авиабилетов**
#
# - **Пиковым днём по заказам является вторник, как для отелей, так и для авиабилетов. Соответственно именно в этот день лучше всего проводить рекламные компании**

# %% [markdown]
# # Средний чек и количество позиций в заказе от времени (по датам)

# %% [markdown]
# - created_dttm - Дата создания заказа
# - order_item_cnt - Количество позиций в заказе
# - nominal_price_eur_amt - Сумма заказа в евро
# - nominal_price_rub_amt - Сумма заказа в рублях

# %% [markdown]
# #### Получаем начальные данные об атрибуте "nominal_price_rub_amt" - сумма заказа в рублях по отелям (HOT) и авиабилетам (AIR)

# %%
print('Пропуски в nominal_price_rub_amt (отели):', df2_HOT['nominal_price_rub_amt'].isna().mean()*100, '%')
print('Пропуски в nominal_price_rub_amt (авиа):', df2_AIR['nominal_price_rub_amt'].isna().mean()*100, '%')
# Out:
# Пропуски в nominal_price_rub_amt (отели): 0.0 %
# Пропуски в nominal_price_rub_amt (авиа): 0.0 %

# %%
start_date = pd.to_datetime('2024-01-01')
end_date = pd.to_datetime('2024-11-01')

df2_HOT_interval = df2_HOT[(df2_HOT['created_dttm']>=start_date) & (df2_HOT['created_dttm']<=end_date)].copy()
df2_AIR_interval = df2_AIR[(df2_AIR['created_dttm']>=start_date) & (df2_AIR['created_dttm']<=end_date)].copy()

df2_HOT_interval = df2_HOT_interval[df2_HOT_interval['order_status_cd']=='SUC']
df2_AIR_interval = df2_AIR_interval[df2_AIR_interval['order_status_cd']=='SUC']

# %%
sns.boxplot(data=pd.concat([df2_HOT_interval, df2_AIR_interval]), y = 'nominal_price_rub_amt', x = 'order_type_cd')
# Out:
# <Axes: xlabel='order_type_cd', ylabel='nominal_price_rub_amt'>

# %%
sns.histplot(data=pd.concat([df2_HOT_interval, df2_AIR_interval]), bins = 60, x='nominal_price_rub_amt', hue='order_type_cd', log_scale=True)
plt.xlabel('Сумма заказа, ₽')
plt.ylabel('Частота')
# Out:
# Text(0, 0.5, 'Частота')

# %% [markdown]
# #### Оцениваем вклад 1% самых дорогих заказов

# %%
quant = df2_HOT_interval['nominal_price_rub_amt'].quantile(0.99)
all_sum_rich_HOT = df2_HOT_interval[df2_HOT_interval['nominal_price_rub_amt'] > quant]['nominal_price_rub_amt'].sum()
all_sum_poor_HOT = df2_HOT_interval[df2_HOT_interval['nominal_price_rub_amt'] <= quant]['nominal_price_rub_amt'].sum()

quant = df2_AIR_interval['nominal_price_rub_amt'].quantile(0.99)
all_sum_rich_AIR = df2_AIR_interval[df2_AIR_interval['nominal_price_rub_amt'] > quant]['nominal_price_rub_amt'].sum()
all_sum_poor_AIR = df2_AIR_interval[df2_AIR_interval['nominal_price_rub_amt'] <= quant]['nominal_price_rub_amt'].sum()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,8))

axes[0].pie([all_sum_poor_HOT, all_sum_rich_HOT], labels=['99% заказов','1% заказов'][::], autopct='%1.1f%%')
axes[0].set_title('Общая стоимость всех заказов для отелей (HOT)')

axes[1].pie([all_sum_poor_AIR, all_sum_rich_AIR], labels=['99% заказов','1% заказов'][::], autopct='%1.1f%%')
axes[1].set_title('Общая стоимость всех заказов для авиабилетов (AIR)')

fig.suptitle('Вклад 1% самых крупных заказов в общий оборот', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# **1% самых дорогих заказов имеет вклад около 12% в общую стоимость всех заказов => имеет смысл приложить достаточно много усилий для привлечения и удержания таких клиентов**

# %% [markdown]
# #### Убираем 1% самых дорогих заказов для лучшего анализа среднего чека основной массы клиентов

# %%
quant = df2_HOT_interval['nominal_price_rub_amt'].quantile(0.99)
df2_HOT_interval = df2_HOT_interval[df2_HOT_interval['nominal_price_rub_amt'] <= quant]

quant = df2_AIR_interval['nominal_price_rub_amt'].quantile(0.99)
df2_AIR_interval = df2_AIR_interval[df2_AIR_interval['nominal_price_rub_amt'] <= quant]

# %%
sns.boxplot(data=pd.concat([df2_HOT_interval, df2_AIR_interval]), y = 'nominal_price_rub_amt', x = 'order_type_cd')
plt.title("Boxplot без 1% самых дорогих", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Boxplot без 1% самых дорогих')

# %% [markdown]
# #### Анализ среднего чека по ДНЯМ для отелей (HOT) и авиабилетам (AIR) без учёта 1% самых дорогих заказов

# %%
hot_avg = df2_HOT_interval.groupby('date')['nominal_price_rub_amt'].mean().reset_index()
air_avg = df2_AIR_interval.groupby('date')['nominal_price_rub_amt'].mean().reset_index()

plt.figure(figsize=(12,4))
sns.lineplot(data=hot_avg, x='date', y='nominal_price_rub_amt')
plt.title('Средний чек по отелям (руб)')
plt.xlabel('Дата')
plt.ylabel('Средний чек, ₽')
plt.show()

plt.figure(figsize=(12,4))
sns.lineplot(data=air_avg, x='date', y='nominal_price_rub_amt')
plt.title('Средний чек по авиабилетам (руб)')
plt.xlabel('Дата')
plt.ylabel('Средний чек, ₽')
plt.show()

# %% [markdown]
# #### Анализ среднего чека и количества заказов по ДНЯМ для отелей (HOT) и авиабилетам (AIR) без учёта 1% самых дорогих заказов

# %%
hot_cnt = df2_HOT_interval.groupby('date').size().reset_index(name='cnt')
hot_avg = df2_HOT_interval.groupby('date')['nominal_price_rub_amt'].mean().reset_index(name='avg')

air_cnt = df2_AIR_interval.groupby('date').size().reset_index(name='cnt')
air_avg = df2_AIR_interval.groupby('date')['nominal_price_rub_amt'].mean().reset_index(name='avg')

hot_daily = hot_cnt.merge(hot_avg, on='date', how='outer').sort_values('date')
hot_daily['cnt_pct'] = hot_daily['cnt'] / hot_daily['cnt'].max() * 100
hot_daily['avg_pct'] = hot_daily['avg'] / hot_daily['avg'].max() * 100

air_daily = air_cnt.merge(air_avg, on='date', how='outer').sort_values('date')
air_daily['cnt_pct'] = air_daily['cnt'] / air_daily['cnt'].max() * 100
air_daily['avg_pct'] = air_daily['avg'] / air_daily['avg'].max() * 100


plt.figure(figsize=(12,5))
sns.lineplot(data=hot_daily, x='date', y='cnt_pct', label='Кол-во заказов, % от max')
sns.lineplot(data=hot_daily, x='date', y='avg_pct', label='Средний чек, % от max')
plt.title('Отели: количество SUC и средний чек (нормировано)')
plt.xlabel('Дата')
plt.ylabel('% от максимума')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


plt.figure(figsize=(12,5))
sns.lineplot(data=air_daily, x='date', y='cnt_pct', label='Кол-во заказов, % от max')
sns.lineplot(data=air_daily, x='date', y='avg_pct', label='Средний чек, % от max')
plt.title('Авиабилеты: количество SUC и средний чек (нормировано)')
plt.xlabel('Дата')
plt.ylabel('% от максимума')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Для отелей явно прослеживается зависимость между пиками бронирований и средним чеком: при снижении стоимости бронирования резко взлетает количество бронирований. Для авиабилетов такая тенденция тоже наблюдается, однако она не так значительна**

# %% [markdown]
# #### Анализ среднего чека по МЕСЯЦАМ для отелей (HOT) и авиабилетам (AIR) без учёта 1% самых дорогих заказов

# %%
hot_avg_month = df2_HOT_interval.groupby('month')['nominal_price_rub_amt'].mean().reset_index(name='avg_month')
hot_cnt_month = df2_HOT_interval.groupby('month').size().reset_index(name='cnt_month')

air_avg_month = df2_AIR_interval.groupby('month')['nominal_price_rub_amt'].mean().reset_index(name='avg_month')
air_cnt_month = df2_AIR_interval.groupby('month').size().reset_index(name='cnt_month')

hot_monthly = hot_avg_month.merge(hot_cnt_month, on='month', how='outer').sort_values('month')
hot_monthly['avg_per_month'] = hot_monthly['avg_month'] / hot_monthly['avg_month'].max() * 100
hot_monthly['cnt_per_month'] = hot_monthly['cnt_month'] / hot_monthly['cnt_month'].max() * 100

air_monthly = air_avg_month.merge(air_cnt_month, on='month', how='outer').sort_values('month')
air_monthly['avg_per_month'] = air_monthly['avg_month'] / air_monthly['avg_month'].max() * 100
air_monthly['cnt_per_month'] = air_monthly['cnt_month'] / air_monthly['cnt_month'].max() * 100

plt.figure(figsize=(12,5))
sns.lineplot(data=hot_monthly, x='month', y='cnt_per_month', label='Кол-во заказов, % от max')
sns.lineplot(data=hot_monthly, x='month', y='avg_per_month', label='Средний чек, % от max')
plt.title('Отели: количество SUC и средний чек (нормировано)')
plt.xlabel('Месяц')
plt.ylabel('% от максимума')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12,5))
sns.lineplot(data=air_monthly, x='month', y='cnt_per_month', label='Кол-во заказов, % от max')
sns.lineplot(data=air_monthly, x='month', y='avg_per_month', label='Средний чек, % от max')
plt.title('Авиабилеты: количество SUC и средний чек (нормировано)')
plt.xlabel('Месяц')
plt.ylabel('% от максимума')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Можно предположить, что есть зависимость между средним чеком и количеством заказов за месяц для отелей. А вот для авиабилетов такой зависимости явно не наблюдается (по крайней мере по ммесяцам). Вероятно, это вызвано тем, что отели часто сами по себе являются целью путешествия (или же то место, где они находятся) из-за чего скидка на бронирование номера логично повышает количество бронирований. Тогда как авиабилет - лишь средство достижения (перелёта) для основного приобретения - отдыха в новом месте и заселения в отель. Поэтому изменение цены авиабилетов не сильно влияет на их покупаемость => привлекать клиентов скидками больший смысл имеет для отелей, чем для авиабилетов**

# %% [markdown]
# # Быстрый осмотр столбцов, отвечающих за уведомления и информирование:
#
# - suppress_email_flg - Отказ от коммуникаций по почте
# - suppress_call_flg - Отказ от коммуникаций по телефону
# - bounce_cd - Код smtp-ответа от почтовой системы (отсутствие кода значит успешную отправку, все остальные smtp-коды в открытом доступе)
# - last_sms_success_flg - Было ли последнее СМС успешным
# - mobile_phone_operator_nm - Оператор мобильной связи
# - last_sms_dt - Дата отправки последнего СМС
# - email_valid_flg - Флаг валидности имейла
# - good_email_address_flg - Флаг хорошего текущего email-адреса (СТОЛБЕЦ УДАЛЁН)
# - bad_email_address_flg - Флаг плохого текущего email-адреса (СТОЛБЕЦ УДАЛЁН)
# - call_contact_6m_flg Был контакт по телефону в последние 6 месяцев (СТОЛБЕЦ УДАЛЁН)
# - call_contact_3m_flg Был контакт по телефону в последние 3 месяца (СТОЛБЕЦ УДАЛЁН)
# - call_contact_1m_flg Был контакт по телефону в последний 1 месяц (СТОЛБЕЦ УДАЛЁН)

# %% [markdown]
# **df2_SUC:**
# - все только успешно совершённые заказы
# - все заказы относят ся либо к HOT либо к AIR

# %%
df2_SUC = df2[df2['order_status_cd'] == 'SUC']

# %% [markdown]
# **df2_NaN:**
# - все уникальные клиенты без заказов
# - нет статусов HOT либо AIR (т.к. заказ не совершён)

# %%
df2_NaN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49053 entries, 59 to 835908
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   order_online_payment_flg     0 non-null      Int64
#  1   client_rk                    49053 non-null  object
#  2   order_rk                     49053 non-null  object
#  3   loyalty_program_type_nm      0 non-null      object
#  4   bundle_nm                    0 non-null      object
#  5   order_type_cd                0 non-null      object
#  6   order_status_cd              0 non-null      object
#  7   party_first_order_dt         0 non-null      datetime64[ns]
#  8   party_first_order_type_dt    0 non-null      datetime64[ns]
#  9   free_cancel_booking_dttm     0 non-null      datetime64[ns]
#  10  created_dttm                 0 non-null      datetime64[ns]
#  11  book_start_dttm              0 non-null      datetime64[ns]
#  12  book_end_dttm                0 non-null      datetime64[ns]
#  13  hotel_country                0 non-null      object
#  14  hotel_city                   0 non-null      object
#  15  avia_dep_city                0 non-null      object
#  16  avia_arr_city                0 non-null      object
#  17  promo_code_discount_amt      0 non-null      float64
#  18  loyalty_accrual_rub_amt      0 non-null      float64
#  19  nominal_price_eur_amt        0 non-null      float64
#  20  nominal_price_rub_amt        0 non-null      float64
#  21  order_item_cnt               0 non-null      float64
#  22  month_beginning_balance_rub  0 non-null      float64
#  23  monthly_income_amt           37000 non-null  float64
#  24  suppress_email_flg           49053 non-null  int64
#  25  suppress_call_flg            49053 non-null  int64
#  26  bounce_cd                    49053 non-null  int64
#  27  last_sms_success_flg         48750 non-null  Int64
#  28  email_valid_flg              49053 non-null  int64
#  29  children_cnt                 38129 non-null  float64
#  30  age                          49052 non-null  float64
#  31  age_type_cd                  49012 non-null  object
#  32  parent_meeting_region_nm     44736 non-null  object
#  33  delivery_region_category_cd  49053 non-null  object
#  34  lvn_city_nm                  28029 non-null  object
#  35  lvn_state_nm                 42273 non-null  object
#  36  last_used_product_cd         49050 non-null  object
#  37  first_used_product_cd        48822 non-null  object
#  38  mobile_phone_operator_nm     48914 non-null  object
#  39  marital_status_cd            27988 non-null  object
#  40  education_level_cd           24251 non-null  object
#  41  gender_cd                    48677 non-null  object
#  42  last_sms_dt                  48750 non-null  datetime64[ns]
# dtypes: Int64(2), datetime64[ns](7), float64(9), int64(4), object(21)
# memory usage: 16.6+ MB

# %% [markdown]
# #### Оценка влияния уведомлений по почте и смс на статус заказа: "успешный" (SUC) или же "не успешный" (NaN)

# %%
print(f"Процент пустых для клиентов без заказов: {df2_NaN.last_sms_success_flg.isna().mean() * 100:.2f}%")
print(f"Процент пустых для успешных (SUC) заказов: {df2_SUC.last_sms_success_flg.isna().mean() * 100:.2f}%")
# Out:
# Процент пустых для клиентов без заказов: 0.62%
# Процент пустых для успешных (SUC) заказов: 0.21%

# %%
print(f"Уникальные значения для клиентов без заказов: {list(df2_SUC.last_sms_success_flg.unique())}")
print(f"Уникальные значения для успешных (SUC) заказов: {list(df2_NaN.last_sms_success_flg.unique())}")
# Out:
# Уникальные значения для клиентов без заказов: [1, 0, <NA>]
# Уникальные значения для успешных (SUC) заказов: [1, 0, <NA>]

# %%
print(f"Среднее значение флага для клиентов без заказов: {df2_NaN.last_sms_success_flg.mean():.2f}")
print(f"Среднее значение флага для успешных (SUC) заказов: {df2_SUC.last_sms_success_flg.mean():.2f}")
# Out:
# Среднее значение флага для клиентов без заказов: 0.81
# Среднее значение флага для успешных (SUC) заказов: 0.84

# %% [markdown]
# - **suppress_email_flg - Отказ от коммуникаций по почте**

# %%
col = 'suppress_email_flg'

# %%
print(f"Процент пустых для клиентов без заказов: {df2_NaN[col].isna().mean() * 100:.2f}%")
print(f"Процент пустых для успешных (SUC) заказов: {df2_SUC[col].isna().mean() * 100:.2f}%")
# Out:
# Процент пустых для клиентов без заказов: 0.00%
# Процент пустых для успешных (SUC) заказов: 0.00%

# %%
print(f"Уникальные значения для клиентов без заказов: {list(df2_SUC[col].unique())}")
print(f"Уникальные значения для успешных (SUC) заказов: {list(df2_NaN[col].unique())}")
# Out:
# Уникальные значения для клиентов без заказов: [0, 1]
# Уникальные значения для успешных (SUC) заказов: [0, 1]

# %%
print(f"Среднее значение флага для клиентов без заказов: {df2_NaN[col].mean():.2f}")
print(f"Среднее значение флага для успешных (SUC) заказов: {df2_SUC[col].mean():.2f}")
# Out:
# Среднее значение флага для клиентов без заказов: 0.01
# Среднее значение флага для успешных (SUC) заказов: 0.01

# %% [markdown]
# - **suppress_call_flg - Отказ от коммуникаций по телефону**

# %%
col = 'suppress_call_flg'

# %%
print(f"Процент пустых для клиентов без заказов: {df2_NaN[col].isna().mean() * 100:.2f}%")
print(f"Процент пустых для успешных (SUC) заказов: {df2_SUC[col].isna().mean() * 100:.2f}%")
# Out:
# Процент пустых для клиентов без заказов: 0.00%
# Процент пустых для успешных (SUC) заказов: 0.00%

# %%
print(f"Уникальные значения для клиентов без заказов: {list(df2_SUC[col].unique())}")
print(f"Уникальные значения для успешных (SUC) заказов: {list(df2_NaN[col].unique())}")
# Out:
# Уникальные значения для клиентов без заказов: [0, 1]
# Уникальные значения для успешных (SUC) заказов: [0, 1]

# %%
print(f"Среднее значение флага для клиентов без заказов: {df2_NaN[col].mean():.2f}")
print(f"Среднее значение флага для успешных (SUC) заказов: {df2_SUC[col].mean():.2f}")
# Out:
# Среднее значение флага для клиентов без заказов: 0.02
# Среднее значение флага для успешных (SUC) заказов: 0.03

# %% [markdown]
# - **email_valid_flg - Флаг валидности имейла**

# %%
col = 'email_valid_flg'

# %%
print(f"Процент пустых для клиентов без заказов: {df2_NaN[col].isna().mean() * 100:.2f}%")
print(f"Процент пустых для успешных (SUC) заказов: {df2_SUC[col].isna().mean() * 100:.2f}%")
# Out:
# Процент пустых для клиентов без заказов: 0.00%
# Процент пустых для успешных (SUC) заказов: 0.00%

# %%
print(f"Уникальные значения для клиентов без заказов: {list(df2_SUC[col].unique())}")
print(f"Уникальные значения для успешных (SUC) заказов: {list(df2_NaN[col].unique())}")
# Out:
# Уникальные значения для клиентов без заказов: [1, 0]
# Уникальные значения для успешных (SUC) заказов: [1, 0]

# %%
print(f"Среднее значение флага для клиентов без заказов: {df2_NaN[col].mean():.2f}")
print(f"Среднее значение флага для успешных (SUC) заказов: {df2_SUC[col].mean():.2f}")
# Out:
# Среднее значение флага для клиентов без заказов: 0.95
# Среднее значение флага для успешных (SUC) заказов: 0.99

# %% [markdown]
# - **bounce_cd - Код smtp-ответа от почтовой системы (отсутствие кода значит успешную отправку, все остальные smtp-коды в открытом доступе)**

# %%
col = 'bounce_cd'

# %%
print(f"Процент пустых для клиентов без заказов: {df2_NaN[col].isna().mean() * 100:.2f}%")
print(f"Процент пустых для успешных (SUC) заказов: {df2_SUC[col].isna().mean() * 100:.2f}%")
# Out:
# Процент пустых для клиентов без заказов: 0.00%
# Процент пустых для успешных (SUC) заказов: 0.00%

# %%
print(f"Уникальные значения для клиентов без заказов: {list(df2_SUC[col].unique())}")
print(f"Уникальные значения для успешных (SUC) заказов: {list(df2_NaN[col].unique())}")
# Out:
# Уникальные значения для клиентов без заказов: [1, 0]
# Уникальные значения для успешных (SUC) заказов: [1, 0]

# %%
print(f"Среднее значение флага для клиентов без заказов: {df2_NaN[col].mean():.2f}")
print(f"Среднее значение флага для успешных (SUC) заказов: {df2_SUC[col].mean():.2f}")
# Out:
# Среднее значение флага для клиентов без заказов: 0.89
# Среднее значение флага для успешных (SUC) заказов: 0.96

# %% [markdown]
# #### Оценка всех флагов уведомлений разом

# %%
df2_all = pd.concat([df2_SUC.assign(target=1), df2_NaN.assign(target=0)], ignore_index=True)

flags = ['suppress_email_flg','suppress_call_flg','last_sms_success_flg','email_valid_flg', 'bounce_cd']

heat = {}
for f in flags:
    heat[f] = df2_all.groupby(f)['target'].mean()

heatmap_df2 = pd.DataFrame(heat).T

# %%
sns.heatmap(heatmap_df2, annot=True, fmt=".2f", cmap="Blues")
plt.title("Доля SUC в зависимости от значения флагов")
plt.xlabel("Значение флага")
plt.ylabel("Флаг")
plt.show()

# %% [markdown]
# **Таким образом наибольшее влияние на совершение заказа оказывают флаги: bounce_cd и email_valid_flg**

# %% [markdown]
# #### Просмотр топ 10 самых используемых операторов у успешных заказов (SUC) и нет (NO_ORDER)

# %%
df2_all = pd.concat([df2_SUC, df2_NaN])
df2_all = df2_all.assign(order_status_cd = df_all['order_status_cd'].fillna('NO_ORDER'))
df2_all = df2_all.assign(target = lambda x )
df2_all['order_status_cd'].unique()
# Out:
# array(['SUC', 'NO_ORDER'], dtype=object)

# %%
top_ops = df2_all['mobile_phone_operator_nm'].value_counts().head(10)
top_ops
# Out:
# mobile_phone_operator_nm
# МТС                 248610
# МегаФон             188137
# Билайн              141408
# TELE2               100664
# Тинькофф Мобайл      74501
# Скартел              40595
# ОАО "Ростелеком"      4395
# МГТС                  1958
# МОТИВ                 1903
# Сбербанк-Телеком      1334
# Name: count, dtype: int64

# %%
sns.countplot(data=df2_all[df2_all['mobile_phone_operator_nm'].isin(top_ops.index)], y='mobile_phone_operator_nm', hue='order_status_cd')
plt.title('Операторы связи и исход заказа')
plt.show()

# %% [markdown]
# #### Процент "неуспешных" (NO_ORDER) от общего колчества по 10 самым популярным операторам

# %%
a = df2_all[df2_all['mobile_phone_operator_nm'].isin(top_ops.index)].groupby(['mobile_phone_operator_nm', 'order_status_cd']).size().unstack()
a
# Out:
# order_status_cd           NO_ORDER     SUC
# mobile_phone_operator_nm
# TELE2                         9209   91455
# Билайн                        8049  133359
# МГТС                           112    1846
# МОТИВ                          184    1719
# МТС                          15247  233363
# МегаФон                       9819  178318
# ОАО "Ростелеком"               358    4037
# Сбербанк-Телеком                76    1258
# Скартел                       2651   37944
# Тинькофф Мобайл               2655   71846

# %%
b = a.assign(per_no_ordered = 100 * a['NO_ORDER'] / (a['NO_ORDER'] + a['SUC']))
b
# Out:
# order_status_cd           NO_ORDER     SUC  per_no_ordered
# mobile_phone_operator_nm
# TELE2                         9209   91455        9.148256
# Билайн                        8049  133359        5.692040
# МГТС                           112    1846        5.720123
# МОТИВ                          184    1719        9.668944
# МТС                          15247  233363        6.132899
# МегаФон                       9819  178318        5.219069
# ОАО "Ростелеком"               358    4037        8.145620
# Сбербанк-Телеком                76    1258        5.697151
# Скартел                       2651   37944        6.530361
# Тинькофф Мобайл               2655   71846        3.563711

# %%
sns.barplot(data=b, x = 'per_no_ordered', y = 'mobile_phone_operator_nm')
plt.xlim(0, 100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# **Каой-либо зависимости между успешным заказом (SUC) и нет (NO_ORDER) для 10 самых популярных операторов также не выявлено**

# %% [markdown]
# #### Самые популярные страны и города для бронирования отеля

# %%
top_country = df2_SUC['hotel_country'].value_counts().head(10)

# %%
sns.barplot?
# Out:
# Signature:
# sns.barplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     order=None,
#     hue_order=None,
#     estimator='mean',
#     errorbar=('ci', 95),
#     n_boot=1000,
#     seed=None,
#     units=None,
#     weights=None,
#     orient=None,
#     color=None,
#     palette=None,
#     saturation=0.75,
#     fill=True,
#     hue_norm=None,
#     width=0.8,
#     dodge='auto',
#     gap=0,
#     log_scale=None,
#     native_scale=False,
#     formatter=None,
#     legend='auto',
#     capsize=0,
#     err_kws=None,
#     ci=<deprecated>,
#     errcolor=<deprecated>,
#     errwidth=<deprecated>,
#     ax=None,
#     **kwargs,
# )
# Docstring:
# Show point estimates and errors as rectangular bars.
#
# A bar plot represents an aggregate or statistical estimate for a numeric
# variable with the height of each rectangle and indicates the uncertainty
# around that estimate using an error bar. Bar plots include 0 in the
# axis range, and they are a good choice when 0 is a meaningful value
# for the variable to take.
#
# See the :ref:`tutorial <categorical_tutorial>` for more information.
#
# .. note::
#     By default, this function treats one of the variables as categorical
#     and draws data at ordinal positions (0, 1, ... n) on the relevant axis.
#     As of version 0.13.0, this can be disabled by setting `native_scale=True`.
#
#
# Parameters
# ----------
# data : DataFrame, Series, dict, array, or list of arrays
#     Dataset for plotting. If `x` and `y` are absent, this is
#     interpreted as wide-form. Otherwise it is expected to be long-form.
# x, y, hue : names of variables in `data` or vector data
#     Inputs for plotting long-form data. See examples for interpretation.
# order, hue_order : lists of strings
#     Order to plot the categorical levels in; otherwise the levels are
#     inferred from the data objects.
# estimator : string or callable that maps vector -> scalar
#     Statistical function to estimate within each categorical bin.
# errorbar : string, (string, number) tuple, callable or None
#     Name of errorbar method (either "ci", "pi", "se", or "sd"), or a tuple
#     with a method name and a level parameter, or a function that maps from a
#     vector to a (min, max) interval, or None to hide errorbar. See the
#     :doc:`errorbar tutorial </tutorial/error_bars>` for more information.
#
#     .. versionadded:: v0.12.0
# n_boot : int
#     Number of bootstrap samples used to compute confidence intervals.
# seed : int, `numpy.random.Generator`, or `numpy.random.RandomState`
#     Seed or random number generator for reproducible bootstrapping.
# units : name of variable in `data` or vector data
#     Identifier of sampling units; used by the errorbar function to
#     perform a multilevel bootstrap and account for repeated measures
# weights : name of variable in `data` or vector data
#     Data values or column used to compute weighted statistics.
#     Note that the use of weights may limit other statistical options.
#
#     .. versionadded:: v0.13.1
# orient : "v" | "h" | "x" | "y"
#     Orientation of the plot (vertical or horizontal). This is usually
#     inferred based on the type of the input variables, but it can be used
#     to resolve ambiguity when both `x` and `y` are numeric or when
#     plotting wide-form data.
#
#     .. versionchanged:: v0.13.0
#         Added 'x'/'y' as options, equivalent to 'v'/'h'.
# color : matplotlib color
#     Single color for the elements in the plot.
# palette : palette name, list, or dict
#     Colors to use for the different levels of the ``hue`` variable. Should
#     be something that can be interpreted by :func:`color_palette`, or a
#     dictionary mapping hue levels to matplotlib colors.
# saturation : float
#     Proportion of the original saturation to draw fill colors in. Large
#     patches often look better with desaturated colors, but set this to
#     `1` if you want the colors to perfectly match the input values.
# fill : bool
#     If True, use a solid patch. Otherwise, draw as line art.
#
#     .. versionadded:: v0.13.0
# hue_norm : tuple or :class:`matplotlib.colors.Normalize` object
#     Normalization in data units for colormap applied to the `hue`
#     variable when it is numeric. Not relevant if `hue` is categorical.
#
#     .. versionadded:: v0.12.0
# width : float
#     Width allotted to each element on the orient axis. When `native_scale=True`,
#     it is relative to the minimum distance between two values in the native scale.
# dodge : "auto" or bool
#     When hue mapping is used, whether elements should be narrowed and shifted along
#     the orient axis to eliminate overlap. If `"auto"`, set to `True` when the
#     orient variable is crossed with the categorical variable or `False` otherwise.
#
#     .. versionchanged:: 0.13.0
#
#         Added `"auto"` mode as a new default.
# gap : float
#     Shrink on the orient axis by this factor to add a gap between dodged elements.
#
#     .. versionadded:: 0.13.0
# log_scale : bool or number, or pair of bools or numbers
#     Set axis scale(s) to log. A single value sets the data axis for any numeric
#     axes in the plot. A pair of values sets each axis independently.
#     Numeric values are interpreted as the desired base (default 10).
#     When `None` or `False`, seaborn defers to the existing Axes scale.
#
#     .. versionadded:: v0.13.0
# native_scale : bool
#     When True, numeric or datetime values on the categorical axis will maintain
#     their original scaling rather than being converted to fixed indices.
#
#     .. versionadded:: v0.13.0
# formatter : callable
#     Function for converting categorical data into strings. Affects both grouping
#     and tick labels.
#
#     .. versionadded:: v0.13.0
# legend : "auto", "brief", "full", or False
#     How to draw the legend. If "brief", numeric `hue` and `size`
#     variables will be represented with a sample of evenly spaced values.
#     If "full", every group will get an entry in the legend. If "auto",
#     choose between brief or full representation based on number of levels.
#     If `False`, no legend data is added and no legend is drawn.
#
#     .. versionadded:: v0.13.0
# capsize : float
#     Width of the "caps" on error bars, relative to bar spacing.
# err_kws : dict
#     Parameters of :class:`matplotlib.lines.Line2D`, for the error bar artists.
#
#     .. versionadded:: v0.13.0
# ci : float
#     Level of the confidence interval to show, in [0, 100].
#
#     .. deprecated:: v0.12.0
#         Use `errorbar=("ci", ...)`.
# errcolor : matplotlib color
#     Color used for the error bar lines.
#
#     .. deprecated:: 0.13.0
#         Use `err_kws={'color': ...}`.
# errwidth : float
#     Thickness of error bar lines (and caps), in points.
#
#     .. deprecated:: 0.13.0
#         Use `err_kws={'linewidth': ...}`.
# ax : matplotlib Axes
#     Axes object to draw the plot onto, otherwise uses the current Axes.
# kwargs : key, value mappings
#     Other parameters are passed through to :class:`matplotlib.patches.Rectangle`.
#
# Returns
# -------
# ax : matplotlib Axes
#     Returns the Axes object with the plot drawn onto it.
#
# See Also
# --------
# countplot : Show the counts of observations in each categorical bin.
# pointplot : Show point estimates and confidence intervals using dots.
# catplot : Combine a categorical plot with a :class:`FacetGrid`.
#
# Notes
# -----
#
# For datasets where 0 is not a meaningful value, a :func:`pointplot` will
# allow you to focus on differences between levels of one or more categorical
# variables.
#
# It is also important to keep in mind that a bar plot shows only the mean (or
# other aggregate) value, but it is often more informative to show the
# distribution of values at each level of the categorical variables. In those
# cases, approaches such as a :func:`boxplot` or :func:`violinplot` may be
# more appropriate.
#
# Examples
# --------
# .. include:: ../docstrings/barplot.rst
# File:      c:\users\petr\useful_programs\anaconda\lib\site-packages\seaborn\categorical.py
# Type:      function

# %%
sns.barplot(y = top_country.index, x = top_country.values)
# Out:
# <Axes: ylabel='hotel_country'>

# %% [markdown]
# **Как видно, подавляющее большинство заказов приходится на Россию, то есть на внутренний туризм**

# %%
top_ind = df2_SUC['hotel_city'].value_counts().head(10).index

# %%
sns.countplot?
# Out:
# Signature:
# sns.countplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     order=None,
#     hue_order=None,
#     orient=None,
#     color=None,
#     palette=None,
#     saturation=0.75,
#     fill=True,
#     hue_norm=None,
#     stat='count',
#     width=0.8,
#     dodge='auto',
#     gap=0,
#     log_scale=None,
#     native_scale=False,
#     formatter=None,
#     legend='auto',
#     ax=None,
#     **kwargs,
# )
# Docstring:
# Show the counts of observations in each categorical bin using bars.
#
# A count plot can be thought of as a histogram across a categorical, instead
# of quantitative, variable. The basic API and options are identical to those
# for :func:`barplot`, so you can compare counts across nested variables.
#
# Note that :func:`histplot` function offers similar functionality with additional
# features (e.g. bar stacking), although its default behavior is somewhat different.
#
# See the :ref:`tutorial <categorical_tutorial>` for more information.
#
# .. note::
#     By default, this function treats one of the variables as categorical
#     and draws data at ordinal positions (0, 1, ... n) on the relevant axis.
#     As of version 0.13.0, this can be disabled by setting `native_scale=True`.
#
#
# Parameters
# ----------
# data : DataFrame, Series, dict, array, or list of arrays
#     Dataset for plotting. If `x` and `y` are absent, this is
#     interpreted as wide-form. Otherwise it is expected to be long-form.
# x, y, hue : names of variables in `data` or vector data
#     Inputs for plotting long-form data. See examples for interpretation.
# order, hue_order : lists of strings
#     Order to plot the categorical levels in; otherwise the levels are
#     inferred from the data objects.
# orient : "v" | "h" | "x" | "y"
#     Orientation of the plot (vertical or horizontal). This is usually
#     inferred based on the type of the input variables, but it can be used
#     to resolve ambiguity when both `x` and `y` are numeric or when
#     plotting wide-form data.
#
#     .. versionchanged:: v0.13.0
#         Added 'x'/'y' as options, equivalent to 'v'/'h'.
# color : matplotlib color
#     Single color for the elements in the plot.
# palette : palette name, list, or dict
#     Colors to use for the different levels of the ``hue`` variable. Should
#     be something that can be interpreted by :func:`color_palette`, or a
#     dictionary mapping hue levels to matplotlib colors.
# saturation : float
#     Proportion of the original saturation to draw fill colors in. Large
#     patches often look better with desaturated colors, but set this to
#     `1` if you want the colors to perfectly match the input values.
# hue_norm : tuple or :class:`matplotlib.colors.Normalize` object
#     Normalization in data units for colormap applied to the `hue`
#     variable when it is numeric. Not relevant if `hue` is categorical.
#
#     .. versionadded:: v0.12.0
# stat : {'count', 'percent', 'proportion', 'probability'}
#     Statistic to compute; when not `'count'`, bar heights will be normalized so that
#     they sum to 100 (for `'percent'`) or 1 (otherwise) across the plot.
#
#     .. versionadded:: v0.13.0
# width : float
#     Width allotted to each element on the orient axis. When `native_scale=True`,
#     it is relative to the minimum distance between two values in the native scale.
# dodge : "auto" or bool
#     When hue mapping is used, whether elements should be narrowed and shifted along
#     the orient axis to eliminate overlap. If `"auto"`, set to `True` when the
#     orient variable is crossed with the categorical variable or `False` otherwise.
#
#     .. versionchanged:: 0.13.0
#
#         Added `"auto"` mode as a new default.
# log_scale : bool or number, or pair of bools or numbers
#     Set axis scale(s) to log. A single value sets the data axis for any numeric
#     axes in the plot. A pair of values sets each axis independently.
#     Numeric values are interpreted as the desired base (default 10).
#     When `None` or `False`, seaborn defers to the existing Axes scale.
#
#     .. versionadded:: v0.13.0
# native_scale : bool
#     When True, numeric or datetime values on the categorical axis will maintain
#     their original scaling rather than being converted to fixed indices.
#
#     .. versionadded:: v0.13.0
# formatter : callable
#     Function for converting categorical data into strings. Affects both grouping
#     and tick labels.
#
#     .. versionadded:: v0.13.0
# legend : "auto", "brief", "full", or False
#     How to draw the legend. If "brief", numeric `hue` and `size`
#     variables will be represented with a sample of evenly spaced values.
#     If "full", every group will get an entry in the legend. If "auto",
#     choose between brief or full representation based on number of levels.
#     If `False`, no legend data is added and no legend is drawn.
#
#     .. versionadded:: v0.13.0
# ax : matplotlib Axes
#     Axes object to draw the plot onto, otherwise uses the current Axes.
# kwargs : key, value mappings
#     Other parameters are passed through to :class:`matplotlib.patches.Rectangle`.
#
# Returns
# -------
# ax : matplotlib Axes
#     Returns the Axes object with the plot drawn onto it.
#
# See Also
# --------
# histplot : Bin and count observations with additional options.
# barplot : Show point estimates and confidence intervals using bars.
# catplot : Combine a categorical plot with a :class:`FacetGrid`.
#
# Examples
# --------
# .. include:: ../docstrings/countplot.rst
# File:      c:\users\petr\useful_programs\anaconda\lib\site-packages\seaborn\categorical.py
# Type:      function

# %%
sns.countplot(data=df2_SUC[df2_SUC['hotel_city'].isin(top_ind)], y = 'hotel_city', order = top_ind)
# Out:
# <Axes: xlabel='count', ylabel='hotel_city'>

# %% [markdown]
# **Как и ожидалось самые популярые города для внутреннего туризма: Москва, Санкт-Петербург и Сочи**

# %% [markdown]
# #### Самые популярные города в которые берут авиабилеты

# %%
top_ind = df2_SUC['avia_arr_city'].value_counts().head(10).index
sns.countplot(data=df2_SUC[df2_SUC['avia_arr_city'].isin(top_ind)], y = 'avia_arr_city', order=top_ind)
# Out:
# <Axes: xlabel='count', ylabel='avia_arr_city'>

# %% [markdown]
# #### Самые популярные города из которых берут авиабилеты

# %%
top_ind = df2_SUC['avia_dep_city'].value_counts().head(10).index
sns.countplot(data=df2_SUC[df2_SUC['avia_dep_city'].isin(top_ind)], y = 'avia_dep_city', order=top_ind)
# Out:
# <Axes: xlabel='count', ylabel='avia_dep_city'>

# %% [markdown]
# **Оба графика (города прилёта и вылета) практически идентичны, то есть клиенты, как правило, покупают возвратные билеты в том же сервисе**

# %% [markdown]
# #### Период бронирования отелей

# %% [markdown]
# **Средняя продолжительность бронирования**

# %%
df2_HOT['stay_length'] = (df2_HOT['book_end_dttm'] - df2_HOT['book_start_dttm']).dt.days

avg_stay = df2_HOT['stay_length'].mean()
print("Средняя продолжительность проживания (дней):", avg_stay)
# Out:
# Средняя продолжительность проживания (дней): 2.1359512558457574

# %% [markdown]
# **Медианная продолжительность бронирования:**

# %%
median_stay = df2_HOT['stay_length'].median()
print("Медианная продолжительность проживания (дней):", median_stay)
# Out:
# Медианная продолжительность проживания (дней): 1.0

# %% [markdown]
# **То есть как минимум 50% клиентов бронирует отели всего на день. Таким образом, должна быть сильная привязка ко дням недели (клиенты заказывают отели на короткий период - выходные):**

# %%
df2_HOT['date'] = df2_HOT['created_dttm'].dt.date
df2_HOT['weekday'] = pd.to_datetime(df2_HOT['date']).dt.day_name()

# %%
df2_HOT['stay_length'].describe()
# Out:
# count    163794.000000
# mean          2.135951
# std           1.911386
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           3.000000
# max          30.000000
# Name: stay_length, dtype: float64

# %%
sns.histplot(df2_HOT['stay_length'], bins=60)
plt.xlabel("Длительность проживания (дней)")
plt.ylabel("Количество заказов")
plt.show()
